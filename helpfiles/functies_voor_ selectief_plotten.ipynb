# %%
import pandas as pd
import numpy as np
import os

# %%
# import dataset Migration movements
print(os.getcwd())

os.chdir("../")
os.chdir("datasets/preprocessed datasets/Temperature and precipitation")
raw_data = pd.read_csv('tas_pr_1991_2015_AC.csv')
df_weather = pd.DataFrame(raw_data)
os.chdir("../../")

print(os.getcwd())
# Out:
# C:\Users\boble\Documents\GitHub\DataProcessing\helpfiles
# C:\Users\boble\Documents\GitHub\DataProcessing\datasets

# %%
# import dataset Temperature and precipitation
print(os.getcwd())

os.chdir("../")
os.chdir("datasets/preprocessed datasets/Migration movements")
raw_data = pd.read_csv('data_africa.csv')
df_migration = pd.DataFrame(raw_data)
os.chdir("../../")

print(os.getcwd())
# Out:
# C:\Users\boble\Documents\GitHub\DataProcessing\datasets
# C:\Users\boble\Documents\GitHub\DataProcessing\datasets

# %%
# import dataset Foodprices
print(os.getcwd())

os.chdir("../")
os.chdir("datasets/preprocessed datasets/Food prices")
raw_data = pd.read_csv('Food_prizes_Africa_processed.csv')
df_foodprices = pd.DataFrame(raw_data)
os.chdir("../../")

print(os.getcwd())
# Out:
# C:\Users\boble\Documents\GitHub\DataProcessing\datasets
# C:\Users\boble\Documents\GitHub\DataProcessing\datasets

# %% [markdown]
# # Plot migration movements

# %%
# selecteer voor een #input_data de #country_of_residence vanuit een bepaalde #origin vanaf #year1 tot en met #year2

def select_plot_migration_movements(input_data, country_of_residence, origin, year1, year2):
    input_data = input_data.loc[input_data['Country of residence'] == country_of_residence]
    if input_data.empty == True:
        return('Error: Country of residence: {} is not included in DataFrame!'.format(country_of_residence))
    input_data = input_data.loc[input_data['Origin'] == origin]
    if input_data.empty == True:
        return('Error: Origin: {} is not included in DataFrame!'.format(country_of_residence))
    input_data = input_data.loc[(input_data['YearMonth'] > year1) & (input_data['YearMonth'] < year2 + 1)]
    return input_data

select_plot_migration_movements(df_migration, 'Netherlands', 'Zimbabwe', 2000, 2012)
# Out:
#       Country of residence    Origin    YearMonth  Values
# 36702          Netherlands  Zimbabwe  2000.250000       1
# 36703          Netherlands  Zimbabwe  2000.333333       1
# 36704          Netherlands  Zimbabwe  2000.416667       2
# 36705          Netherlands  Zimbabwe  2000.666667       4
# 36706          Netherlands  Zimbabwe  2000.750000       1
# 36768          Netherlands  Zimbabwe  2001.833333       1
# 36875          Netherlands  Zimbabwe  2002.333333       2
# 36876          Netherlands  Zimbabwe  2002.500000       4
# 36877          Netherlands  Zimbabwe  2002.583333       1
# 36878          Netherlands  Zimbabwe  2002.750000       3
# 36879          Netherlands  Zimbabwe  2002.916667       1
# 37013          Netherlands  Zimbabwe  2003.000000       1
# 37014          Netherlands  Zimbabwe  2003.166667       1
# 37015          Netherlands  Zimbabwe  2003.333333       2
# 37016          Netherlands  Zimbabwe  2003.500000       1
# 37017          Netherlands  Zimbabwe  2003.583333       2
# 37018          Netherlands  Zimbabwe  2003.750000       1
# 37019          Netherlands  Zimbabwe  2003.916667       1
# 37155          Netherlands  Zimbabwe  2004.000000       1
# 37156          Netherlands  Zimbabwe  2004.166667       2
# 37157          Netherlands  Zimbabwe  2004.250000       1
# 37158          Netherlands  Zimbabwe  2004.666667       1
# 37159          Netherlands  Zimbabwe  2004.750000       1
# 37160          Netherlands  Zimbabwe  2004.833333       1
# 37161          Netherlands  Zimbabwe  2004.916667       1
# 37302          Netherlands  Zimbabwe  2005.250000       2
# 37303          Netherlands  Zimbabwe  2005.500000       2
# 37304          Netherlands  Zimbabwe  2005.916667       4
# 37435          Netherlands  Zimbabwe  2006.083333       2
# 37436          Netherlands  Zimbabwe  2006.166667       1
# ...                    ...       ...          ...     ...
# 37734          Netherlands  Zimbabwe  2008.166667       1
# 37735          Netherlands  Zimbabwe  2008.250000       1
# 37736          Netherlands  Zimbabwe  2008.333333       5
# 37737          Netherlands  Zimbabwe  2008.416667       1
# 37738          Netherlands  Zimbabwe  2008.583333       2
# 37902          Netherlands  Zimbabwe  2009.000000       1
# 37903          Netherlands  Zimbabwe  2009.166667       3
# 37904          Netherlands  Zimbabwe  2009.250000       4
# 37905          Netherlands  Zimbabwe  2009.416667       3
# 37906          Netherlands  Zimbabwe  2009.666667       1
# 37907          Netherlands  Zimbabwe  2009.750000       1
# 38066          Netherlands  Zimbabwe  2010.083333       1
# 38067          Netherlands  Zimbabwe  2010.166667       3
# 38068          Netherlands  Zimbabwe  2010.250000       3
# 38069          Netherlands  Zimbabwe  2010.333333       2
# 38070          Netherlands  Zimbabwe  2010.416667       2
# 38071          Netherlands  Zimbabwe  2010.666667       3
# 38072          Netherlands  Zimbabwe  2010.750000       2
# 38073          Netherlands  Zimbabwe  2010.833333       1
# 38205          Netherlands  Zimbabwe  2011.000000       2
# 38206          Netherlands  Zimbabwe  2011.250000       2
# 38207          Netherlands  Zimbabwe  2011.333333       2
# 38208          Netherlands  Zimbabwe  2011.583333       2
# 38209          Netherlands  Zimbabwe  2011.666667       1
# 38210          Netherlands  Zimbabwe  2011.750000       1
# 38211          Netherlands  Zimbabwe  2011.916667       1
# 38331          Netherlands  Zimbabwe  2012.000000       1
# 38332          Netherlands  Zimbabwe  2012.083333       1
# 38333          Netherlands  Zimbabwe  2012.166667       1
# 38334          Netherlands  Zimbabwe  2012.416667       1
#
# [70 rows x 4 columns]

# %%
test = select_plot_migration_movements(df_migration, 'Germany', 'Zimbabwe', 1999, 2017)

# %% [markdown]
# # Plot temperature and precipitation

# %%
# geeft voor een #input_data van een #country de pr en tas vanaf #year1 tot en met #year2

def select_plot_temperature_and_precipitation(input_data, country, year1, year2):
    saved_dict = {'Mauritania': 'MRT', 'Lesotho': 'LSO', 'Somalia': 'SOM', 'Nigeria': 'NGA', 'Tanzania': 'TZA', 'Zambia': 'ZMB', 'Burundi': 'BDI', 'Afghanistan': 'AFG', 'Mali': 'MLI', 'Niger': 'NER', 'Malawi': 'MWI', 'Congo': 'ZAR', 'Cabo Verde': 'CPV', 'Sudan': 'SDN', 'Pakistan': 'PAK', 'Burkina Baso': 'BFA', 'Rwanda': 'RWA', 'Kenya': 'KEN', 'Senegal': 'SEN', 'Cameroon': 'CMR', 'Sierra Leone': 'SLE', 'Iraq': 'IRQ', 'Uganda': 'UGA', 'Mozambique': 'MOZ', 'Zimbabwe': 'ZWE', 'Central African Republic': 'CAF', 'Ethiopia': 'ETH', 'Guinea': 'GIN', 'Liberia': 'LBR', 'Djibouti': 'DJI', 'Iran': 'IRN', 'Madagascar': 'MDG', 'Lebanon': 'LBN'}

    if country in saved_dict.keys():
        country = saved_dict[country]
    else:
        print("Please enter correct country name")
    
    input_data = pd.DataFrame(input_data.loc[input_data['country'] == country])
    input_data = input_data.loc[(input_data['year'] > year1 - 1) & (input_data['year'] < year2 + 1)]
    
#     maak van de jaren en maanden kommajaren
    YearMonth = []
    month = []
    for row in input_data['month']:
        month.append(str(row))
        
    count = 0
    for year in input_data['year']:
        year = int(year) + (int(month[count])  - 1)/ 12
        YearMonth.append(year)
        count += 1
    input_data['YearMonth'] = YearMonth
    input_data = input_data[['pr', 'tas', 'country', 'YearMonth']]
    return input_data

select_plot_temperature_and_precipitation(df_weather, 'Mali', 1990, 2030)
# Out:
#              pr      tas country    YearMonth
# 5400    0.01508  21.6057     MLI  1991.000000
# 5401    0.56483  24.3036     MLI  1991.083333
# 5402    1.09565  27.6491     MLI  1991.166667
# 5403    4.37197  30.9279     MLI  1991.250000
# 5404   18.05700  32.3465     MLI  1991.333333
# 5405   32.44580  33.9143     MLI  1991.416667
# 5406   83.04910  31.5855     MLI  1991.500000
# 5407  101.54800  30.3319     MLI  1991.583333
# 5408   39.44210  31.5396     MLI  1991.666667
# 5409   21.18050  29.3711     MLI  1991.750000
# 5410    0.26743  26.0599     MLI  1991.833333
# 5411    0.00648  21.2019     MLI  1991.916667
# 5412    0.14817  19.5778     MLI  1992.000000
# 5413    0.25789  23.9248     MLI  1992.083333
# 5414    0.46225  26.3411     MLI  1992.166667
# 5415    2.66652  30.5582     MLI  1992.250000
# 5416   18.13470  32.5249     MLI  1992.333333
# 5417   36.20810  33.9521     MLI  1992.416667
# 5418   75.85430  31.5502     MLI  1992.500000
# 5419   98.66620  30.3410     MLI  1992.583333
# 5420   45.52770  30.7449     MLI  1992.666667
# 5421    8.19965  29.6090     MLI  1992.750000
# 5422    0.85145  24.4982     MLI  1992.833333
# 5423    0.01343  22.7834     MLI  1992.916667
# 5424    0.00452  20.1276     MLI  1993.000000
# 5425    0.26246  24.1416     MLI  1993.083333
# 5426    2.24747  28.2229     MLI  1993.166667
# 5427    4.40611  31.4446     MLI  1993.250000
# 5428    7.95037  33.7122     MLI  1993.333333
# 5429   33.58970  34.1178     MLI  1993.416667
# ...         ...      ...     ...          ...
# 5670   65.48100  32.4992     MLI  2013.500000
# 5671  125.57600  30.3724     MLI  2013.583333
# 5672   59.67560  30.8802     MLI  2013.666667
# 5673   20.16610  29.7825     MLI  2013.750000
# 5674    0.60011  25.9851     MLI  2013.833333
# 5675    0.05238  21.6157     MLI  2013.916667
# 5676    0.20456  22.7381     MLI  2014.000000
# 5677    0.38949  24.0982     MLI  2014.083333
# 5678    0.86751  27.4938     MLI  2014.166667
# 5679    6.52043  32.4196     MLI  2014.250000
# 5680   23.97690  33.7126     MLI  2014.333333
# 5681   42.01600  34.7070     MLI  2014.416667
# 5682   63.54380  32.7382     MLI  2014.500000
# 5683  104.80300  31.0702     MLI  2014.583333
# 5684   61.59500  30.7360     MLI  2014.666667
# 5685   22.43950  30.2707     MLI  2014.750000
# 5686    1.57904  26.4151     MLI  2014.833333
# 5687    0.01602  22.1357     MLI  2014.916667
# 5688    0.01477  20.9795     MLI  2015.000000
# 5689    0.58457  24.8925     MLI  2015.083333
# 5690    0.41521  27.6319     MLI  2015.166667
# 5691    2.64127  31.6798     MLI  2015.250000
# 5692   10.20730  35.3688     MLI  2015.333333
# 5693   31.24610  34.8287     MLI  2015.416667
# 5694   82.16890  32.3511     MLI  2015.500000
# 5695  123.60500  30.5322     MLI  2015.583333
# 5696   54.24420  32.1935     MLI  2015.666667
# 5697   22.20400  30.7292     MLI  2015.750000
# 5698    0.68673  26.5192     MLI  2015.833333
# 5699    0.00659  21.0909     MLI  2015.916667
#
# [300 rows x 4 columns]

# %%
df_foodprices
# Out:
#         Unnamed: 0     adm0_name         adm1_name                 mkt_name  \
# 0            24213  Burkina Faso          Cascades                  Banfora
# 1            24214  Burkina Faso          Cascades                  Banfora
# 2            24215  Burkina Faso          Cascades                  Banfora
# 3            24216  Burkina Faso          Cascades                  Banfora
# 4            24217  Burkina Faso          Cascades                  Banfora
# 5            24218  Burkina Faso          Cascades                  Banfora
# 6            24219  Burkina Faso          Cascades                  Banfora
# 7            24220  Burkina Faso          Cascades                  Banfora
# 8            24221  Burkina Faso          Cascades                  Banfora
# 9            24222  Burkina Faso          Cascades                  Banfora
# 10           24223  Burkina Faso          Cascades                  Banfora
# 11           24224  Burkina Faso          Cascades                  Banfora
# 12           24225  Burkina Faso          Cascades                  Banfora
# 13           24226  Burkina Faso          Cascades                  Banfora
# 14           24227  Burkina Faso          Cascades                  Banfora
# 15           24228  Burkina Faso          Cascades                  Banfora
# 16           24229  Burkina Faso          Cascades                  Banfora
# 17           24230  Burkina Faso          Cascades                  Banfora
# 18           24231  Burkina Faso          Cascades                  Banfora
# 19           24232  Burkina Faso          Cascades                  Banfora
# 20           24233  Burkina Faso          Cascades                  Banfora
# 21           24234  Burkina Faso          Cascades                  Banfora
# 22           24235  Burkina Faso          Cascades                  Banfora
# 23           24236  Burkina Faso          Cascades                  Banfora
# 24           24237  Burkina Faso          Cascades                  Banfora
# 25           24238  Burkina Faso          Cascades                  Banfora
# 26           24239  Burkina Faso          Cascades                  Banfora
# 27           24240  Burkina Faso          Cascades                  Banfora
# 28           24241  Burkina Faso          Cascades                  Banfora
# 29           24242  Burkina Faso          Cascades                  Banfora
# ...            ...           ...               ...                      ...
# 408040      765105      Zimbabwe  Mashonaland West  Negande business centre
# 408041      765106      Zimbabwe  Mashonaland West  Negande business centre
# 408042      765107      Zimbabwe  Mashonaland West  Negande business centre
# 408043      765108      Zimbabwe  Mashonaland West  Negande business centre
# 408044      765109      Zimbabwe  Mashonaland West  Negande business centre
# 408045      765110      Zimbabwe  Mashonaland West  Negande business centre
# 408046      765111      Zimbabwe  Mashonaland West  Negande business centre
# 408047      765112      Zimbabwe  Mashonaland West                 Kasvisva
# 408048      765113      Zimbabwe  Mashonaland West                 Kasvisva
# 408049      765114      Zimbabwe  Mashonaland West                 Kasvisva
# 408050      765115      Zimbabwe  Mashonaland West                 Kasvisva
# 408051      765116      Zimbabwe  Mashonaland West                 Kasvisva
# 408052      765117      Zimbabwe  Mashonaland West                 Kasvisva
# 408053      765118      Zimbabwe  Mashonaland West                 Kasvisva
# 408054      765119      Zimbabwe  Mashonaland West                     Mola
# 408055      765120      Zimbabwe  Mashonaland West                     Mola
# 408056      765121      Zimbabwe  Mashonaland West                     Mola
# 408057      765122      Zimbabwe  Mashonaland West                     Mola
# 408058      765123      Zimbabwe  Mashonaland West                     Mola
# 408059      765124      Zimbabwe  Mashonaland West                     Mola
# 408060      765125      Zimbabwe  Mashonaland West                     Mola
# 408061      765126      Zimbabwe  Mashonaland West                     Mola
# 408062      765127      Zimbabwe  Mashonaland West                     Mola
# 408063      765128      Zimbabwe  Mashonaland West                     Mola
# 408064      765129      Zimbabwe  Mashonaland West                     Mola
# 408065      765130      Zimbabwe  Mashonaland West                     Mola
# 408066      765131      Zimbabwe  Mashonaland West                     Mola
# 408067      765132      Zimbabwe  Mashonaland West                     Mola
# 408068      765133      Zimbabwe  Mashonaland West                     Mola
# 408069      765134      Zimbabwe  Mashonaland West                     Mola
#
#                            cm_name cur_name pt_name  um_id um_name  mp_month  \
# 0                            Maize      XOF  Retail      5      KG         1
# 1                            Maize      XOF  Retail      5      KG         2
# 2                            Maize      XOF  Retail      5      KG         3
# 3                            Maize      XOF  Retail      5      KG         4
# 4                            Maize      XOF  Retail      5      KG         5
# 5                            Maize      XOF  Retail      5      KG         6
# 6                            Maize      XOF  Retail      5      KG         7
# 7                            Maize      XOF  Retail      5      KG         8
# 8                            Maize      XOF  Retail      5      KG         9
# 9                            Maize      XOF  Retail      5      KG        10
# 10                           Maize      XOF  Retail      5      KG        11
# 11                           Maize      XOF  Retail      5      KG        12
# 12                           Maize      XOF  Retail      5      KG         1
# 13                           Maize      XOF  Retail      5      KG         2
# 14                           Maize      XOF  Retail      5      KG         3
# 15                           Maize      XOF  Retail      5      KG         4
# 16                           Maize      XOF  Retail      5      KG         5
# 17                           Maize      XOF  Retail      5      KG         6
# 18                           Maize      XOF  Retail      5      KG         7
# 19                           Maize      XOF  Retail      5      KG         8
# 20                           Maize      XOF  Retail      5      KG         9
# 21                           Maize      XOF  Retail      5      KG        10
# 22                           Maize      XOF  Retail      5      KG        11
# 23                           Maize      XOF  Retail      5      KG        12
# 24                           Maize      XOF  Retail      5      KG         1
# 25                           Maize      XOF  Retail      5      KG         2
# 26                           Maize      XOF  Retail      5      KG         3
# 27                           Maize      XOF  Retail      5      KG         4
# 28                           Maize      XOF  Retail      5      KG         5
# 29                           Maize      XOF  Retail      5      KG         6
# ...                            ...      ...     ...    ...     ...       ...
# 408040                       Maize      USD  Retail      5      KG         9
# 408041                       Maize      USD  Retail      5      KG        10
# 408042                     Sorghum      USD  Retail      5      KG         9
# 408043                     Sorghum      USD  Retail      5      KG        10
# 408044             Oil (vegetable)      USD  Retail     15       L         9
# 408045             Oil (vegetable)      USD  Retail     15       L        10
# 408046  Oil (vegetable, fortified)      USD  Retail     15       L        10
# 408047                       Maize      USD  Retail      5      KG        10
# 408048                     Sorghum      USD  Retail      5      KG         9
# 408049                     Sorghum      USD  Retail      5      KG        10
# 408050             Oil (vegetable)      USD  Retail     15       L         9
# 408051             Oil (vegetable)      USD  Retail     15       L        10
# 408052        Groundnuts (shelled)      USD  Retail      5      KG        10
# 408053  Oil (vegetable, fortified)      USD  Retail     15       L        10
# 408054                       Beans      USD  Retail      5      KG         8
# 408055                       Beans      USD  Retail      5      KG         9
# 408056                       Beans      USD  Retail      5      KG        10
# 408057                       Maize      USD  Retail      5      KG         8
# 408058                       Maize      USD  Retail      5      KG         9
# 408059                       Maize      USD  Retail      5      KG        10
# 408060                     Sorghum      USD  Retail      5      KG         8
# 408061                     Sorghum      USD  Retail      5      KG         9
# 408062                     Sorghum      USD  Retail      5      KG        10
# 408063                      Millet      USD  Retail      5      KG         8
# 408064             Oil (vegetable)      USD  Retail     15       L         8
# 408065             Oil (vegetable)      USD  Retail     15       L         9
# 408066             Oil (vegetable)      USD  Retail     15       L        10
# 408067        Groundnuts (shelled)      USD  Retail      5      KG         8
# 408068  Maize meal (white, roller)      USD  Retail      5      KG         8
# 408069  Oil (vegetable, fortified)      USD  Retail     15       L        10
#
#         mp_year  mp_price         Year
# 0          2003  105.6558  2003.000000
# 1          2003  103.3953  2003.083333
# 2          2003  101.8303  2003.166667
# 3          2003  103.3039  2003.250000
# 4          2003  103.7575  2003.333333
# 5          2003  102.4965  2003.416667
# 6          2003   82.3070  2003.500000
# 7          2003   76.6009  2003.583333
# 8          2003   71.1824  2003.666667
# 9          2003   53.1701  2003.750000
# 10         2003   52.2340  2003.833333
# 11         2003   50.2570  2003.916667
# 12         2004   50.3069  2004.000000
# 13         2004   48.0672  2004.083333
# 14         2004   51.7204  2004.166667
# 15         2004   59.2121  2004.250000
# 16         2004   62.8178  2004.333333
# 17         2004   62.4239  2004.416667
# 18         2004   73.8951  2004.500000
# 19         2004   75.1852  2004.583333
# 20         2004   87.9618  2004.666667
# 21         2004   92.6165  2004.750000
# 22         2004   88.9691  2004.833333
# 23         2004   86.4592  2004.916667
# 24         2005   86.6973  2005.000000
# 25         2005  114.4360  2005.083333
# 26         2005  141.3891  2005.166667
# 27         2005  149.0165  2005.250000
# 28         2005  158.8906  2005.333333
# 29         2005  200.3926  2005.416667
# ...         ...       ...          ...
# 408040     2017    0.2900  2017.666667
# 408041     2017    0.4000  2017.750000
# 408042     2017    0.2900  2017.666667
# 408043     2017    0.2900  2017.750000
# 408044     2017    2.3800  2017.666667
# 408045     2017    3.0000  2017.750000
# 408046     2017    3.0000  2017.750000
# 408047     2017    0.1700  2017.750000
# 408048     2017    0.1400  2017.666667
# 408049     2017    0.1400  2017.750000
# 408050     2017    2.3800  2017.666667
# 408051     2017    2.2500  2017.750000
# 408052     2017    0.2900  2017.750000
# 408053     2017    2.2500  2017.750000
# 408054     2017    2.9000  2017.583333
# 408055     2017    3.0000  2017.666667
# 408056     2017    3.0000  2017.750000
# 408057     2017    0.2900  2017.583333
# 408058     2017    0.2900  2017.666667
# 408059     2017    0.2300  2017.750000
# 408060     2017    0.2900  2017.583333
# 408061     2017    0.2300  2017.666667
# 408062     2017    0.2300  2017.750000
# 408063     2017    0.2900  2017.583333
# 408064     2017    1.9800  2017.583333
# 408065     2017    2.3800  2017.666667
# 408066     2017    2.5000  2017.750000
# 408067     2017    0.4600  2017.583333
# 408068     2017    0.7300  2017.583333
# 408069     2017    2.5000  2017.750000
#
# [408070 rows x 13 columns]

# %% [markdown]
# # Plot foodprices per market

# %%
def select_plot_foodprices_per_market(input_data, country, product, year1, year2):
    input_data = input_data.loc[input_data['adm0_name'] == country]
    input_data = input_data.loc[input_data['cm_name'] == product]
    input_data = input_data.loc[(input_data['Year'] >= year1) & (input_data['Year'] < year2 + 1)]
    return input_data

select_plot_foodprices_per_market(df_foodprices, 'Burkina Faso', 'Maize', 2004, 2004)
# Out:
#       Unnamed: 0     adm0_name          adm1_name                 mkt_name  \
# 12         24225  Burkina Faso           Cascades                  Banfora
# 13         24226  Burkina Faso           Cascades                  Banfora
# 14         24227  Burkina Faso           Cascades                  Banfora
# 15         24228  Burkina Faso           Cascades                  Banfora
# 16         24229  Burkina Faso           Cascades                  Banfora
# 17         24230  Burkina Faso           Cascades                  Banfora
# 18         24231  Burkina Faso           Cascades                  Banfora
# 19         24232  Burkina Faso           Cascades                  Banfora
# 20         24233  Burkina Faso           Cascades                  Banfora
# 21         24234  Burkina Faso           Cascades                  Banfora
# 22         24235  Burkina Faso           Cascades                  Banfora
# 23         24236  Burkina Faso           Cascades                  Banfora
# 1103       25316  Burkina Faso          Sud-ouest                Diebougou
# 1104       25317  Burkina Faso          Sud-ouest                Diebougou
# 1105       25318  Burkina Faso          Sud-ouest                Diebougou
# 1106       25319  Burkina Faso          Sud-ouest                Diebougou
# 1107       25320  Burkina Faso          Sud-ouest                Diebougou
# 1108       25321  Burkina Faso          Sud-ouest                Diebougou
# 1109       25322  Burkina Faso          Sud-ouest                Diebougou
# 1110       25323  Burkina Faso          Sud-ouest                Diebougou
# 1111       25324  Burkina Faso          Sud-ouest                Diebougou
# 1112       25325  Burkina Faso          Sud-ouest                Diebougou
# 1113       25326  Burkina Faso          Sud-ouest                Diebougou
# 1114       25327  Burkina Faso          Sud-ouest                Diebougou
# 1790       26003  Burkina Faso              Sahel                    Djibo
# 1791       26004  Burkina Faso              Sahel                    Djibo
# 1792       26005  Burkina Faso              Sahel                    Djibo
# 1793       26006  Burkina Faso              Sahel                    Djibo
# 1794       26007  Burkina Faso              Sahel                    Djibo
# 1795       26008  Burkina Faso              Sahel                    Djibo
# ...          ...           ...                ...                      ...
# 5969       30182  Burkina Faso             Centre  Ouagadougo (Sankaryare)
# 5970       30183  Burkina Faso             Centre  Ouagadougo (Sankaryare)
# 5971       30184  Burkina Faso             Centre  Ouagadougo (Sankaryare)
# 5972       30185  Burkina Faso             Centre  Ouagadougo (Sankaryare)
# 5973       30186  Burkina Faso             Centre  Ouagadougo (Sankaryare)
# 5974       30187  Burkina Faso             Centre  Ouagadougo (Sankaryare)
# 6644       30857  Burkina Faso         Centre-est                Tenkodogo
# 6645       30858  Burkina Faso         Centre-est                Tenkodogo
# 6646       30859  Burkina Faso         Centre-est                Tenkodogo
# 6647       30860  Burkina Faso         Centre-est                Tenkodogo
# 6648       30861  Burkina Faso         Centre-est                Tenkodogo
# 6649       30862  Burkina Faso         Centre-est                Tenkodogo
# 6650       30863  Burkina Faso         Centre-est                Tenkodogo
# 6651       30864  Burkina Faso         Centre-est                Tenkodogo
# 6652       30865  Burkina Faso         Centre-est                Tenkodogo
# 6653       30866  Burkina Faso         Centre-est                Tenkodogo
# 6654       30867  Burkina Faso         Centre-est                Tenkodogo
# 6655       30868  Burkina Faso         Centre-est                Tenkodogo
# 7208       31421  Burkina Faso  Boucle Du Mouhoun                   Tougan
# 7209       31422  Burkina Faso  Boucle Du Mouhoun                   Tougan
# 7210       31423  Burkina Faso  Boucle Du Mouhoun                   Tougan
# 7211       31424  Burkina Faso  Boucle Du Mouhoun                   Tougan
# 7212       31425  Burkina Faso  Boucle Du Mouhoun                   Tougan
# 7213       31426  Burkina Faso  Boucle Du Mouhoun                   Tougan
# 7214       31427  Burkina Faso  Boucle Du Mouhoun                   Tougan
# 7215       31428  Burkina Faso  Boucle Du Mouhoun                   Tougan
# 7216       31429  Burkina Faso  Boucle Du Mouhoun                   Tougan
# 7217       31430  Burkina Faso  Boucle Du Mouhoun                   Tougan
# 7218       31431  Burkina Faso  Boucle Du Mouhoun                   Tougan
# 7219       31432  Burkina Faso  Boucle Du Mouhoun                   Tougan
#
#      cm_name cur_name pt_name  um_id um_name  mp_month  mp_year  mp_price  \
# 12     Maize      XOF  Retail      5      KG         1     2004   50.3069
# 13     Maize      XOF  Retail      5      KG         2     2004   48.0672
# 14     Maize      XOF  Retail      5      KG         3     2004   51.7204
# 15     Maize      XOF  Retail      5      KG         4     2004   59.2121
# 16     Maize      XOF  Retail      5      KG         5     2004   62.8178
# 17     Maize      XOF  Retail      5      KG         6     2004   62.4239
# 18     Maize      XOF  Retail      5      KG         7     2004   73.8951
# 19     Maize      XOF  Retail      5      KG         8     2004   75.1852
# 20     Maize      XOF  Retail      5      KG         9     2004   87.9618
# 21     Maize      XOF  Retail      5      KG        10     2004   92.6165
# 22     Maize      XOF  Retail      5      KG        11     2004   88.9691
# 23     Maize      XOF  Retail      5      KG        12     2004   86.4592
# 1103   Maize      XOF  Retail      5      KG         1     2004   56.5478
# 1104   Maize      XOF  Retail      5      KG         2     2004   61.0210
# 1105   Maize      XOF  Retail      5      KG         3     2004   72.9214
# 1106   Maize      XOF  Retail      5      KG         4     2004   77.2668
# 1107   Maize      XOF  Retail      5      KG         5     2004   84.4684
# 1108   Maize      XOF  Retail      5      KG         6     2004   84.9492
# 1109   Maize      XOF  Retail      5      KG         7     2004   80.6857
# 1110   Maize      XOF  Retail      5      KG         8     2004   90.0479
# 1111   Maize      XOF  Retail      5      KG         9     2004   93.6703
# 1112   Maize      XOF  Retail      5      KG        10     2004   93.6382
# 1113   Maize      XOF  Retail      5      KG        11     2004  104.8095
# 1114   Maize      XOF  Retail      5      KG        12     2004   99.0356
# 1790   Maize      XOF  Retail      5      KG         1     2004   88.0211
# 1791   Maize      XOF  Retail      5      KG         2     2004   88.2353
# 1792   Maize      XOF  Retail      5      KG         3     2004   88.8349
# 1793   Maize      XOF  Retail      5      KG         4     2004  100.9709
# 1794   Maize      XOF  Retail      5      KG         5     2004   99.7573
# 1795   Maize      XOF  Retail      5      KG         6     2004   97.4529
# ...      ...      ...     ...    ...     ...       ...      ...       ...
# 5969   Maize      XOF  Retail      5      KG         7     2004  108.9805
# 5970   Maize      XOF  Retail      5      KG         8     2004  122.0238
# 5971   Maize      XOF  Retail      5      KG         9     2004  120.4158
# 5972   Maize      XOF  Retail      5      KG        10     2004  132.9089
# 5973   Maize      XOF  Retail      5      KG        11     2004  133.9667
# 5974   Maize      XOF  Retail      5      KG        12     2004  128.8328
# 6644   Maize      XOF  Retail      5      KG         1     2004   73.7969
# 6645   Maize      XOF  Retail      5      KG         2     2004   69.5134
# 6646   Maize      XOF  Retail      5      KG         3     2004   81.7805
# 6647   Maize      XOF  Retail      5      KG         4     2004   81.7805
# 6648   Maize      XOF  Retail      5      KG         5     2004   81.7805
# 6649   Maize      XOF  Retail      5      KG         6     2004   83.6208
# 6650   Maize      XOF  Retail      5      KG         7     2004   97.0899
# 6651   Maize      XOF  Retail      5      KG         8     2004  102.4863
# 6652   Maize      XOF  Retail      5      KG         9     2004  100.4832
# 6653   Maize      XOF  Retail      5      KG        10     2004  100.8333
# 6654   Maize      XOF  Retail      5      KG        11     2004  110.3429
# 6655   Maize      XOF  Retail      5      KG        12     2004  123.8889
# 7208   Maize      XOF  Retail      5      KG         1     2004   95.3125
# 7209   Maize      XOF  Retail      5      KG         2     2004   93.9453
# 7210   Maize      XOF  Retail      5      KG         3     2004   92.1875
# 7211   Maize      XOF  Retail      5      KG         4     2004   86.7188
# 7212   Maize      XOF  Retail      5      KG         5     2004   90.6250
# 7213   Maize      XOF  Retail      5      KG         6     2004   89.0625
# 7214   Maize      XOF  Retail      5      KG         7     2004  100.3906
# 7215   Maize      XOF  Retail      5      KG         8     2004   96.5071
# 7216   Maize      XOF  Retail      5      KG         9     2004   91.1078
# 7217   Maize      XOF  Retail      5      KG        10     2004   96.4613
# 7218   Maize      XOF  Retail      5      KG        11     2004  124.1628
# 7219   Maize      XOF  Retail      5      KG        12     2004  122.8405
#
#              Year
# 12    2004.000000
# 13    2004.083333
# 14    2004.166667
# 15    2004.250000
# 16    2004.333333
# 17    2004.416667
# 18    2004.500000
# 19    2004.583333
# 20    2004.666667
# 21    2004.750000
# 22    2004.833333
# 23    2004.916667
# 1103  2004.000000
# 1104  2004.083333
# 1105  2004.166667
# 1106  2004.250000
# 1107  2004.333333
# 1108  2004.416667
# 1109  2004.500000
# 1110  2004.583333
# 1111  2004.666667
# 1112  2004.750000
# 1113  2004.833333
# 1114  2004.916667
# 1790  2004.000000
# 1791  2004.083333
# 1792  2004.166667
# 1793  2004.250000
# 1794  2004.333333
# 1795  2004.416667
# ...           ...
# 5969  2004.500000
# 5970  2004.583333
# 5971  2004.666667
# 5972  2004.750000
# 5973  2004.833333
# 5974  2004.916667
# 6644  2004.000000
# 6645  2004.083333
# 6646  2004.166667
# 6647  2004.250000
# 6648  2004.333333
# 6649  2004.416667
# 6650  2004.500000
# 6651  2004.583333
# 6652  2004.666667
# 6653  2004.750000
# 6654  2004.833333
# 6655  2004.916667
# 7208  2004.000000
# 7209  2004.083333
# 7210  2004.166667
# 7211  2004.250000
# 7212  2004.333333
# 7213  2004.416667
# 7214  2004.500000
# 7215  2004.583333
# 7216  2004.666667
# 7217  2004.750000
# 7218  2004.833333
# 7219  2004.916667
#
# [119 rows x 13 columns]

# %%
# 

def select_plot_foodprices_average(input_data, country, product, year1, year2):
    input_data = select_plot_foodprices_per_market(input_data, country, product, year1, year2)
    
    country_list = []
    product_list = []
    average_price_list = []
    year_list = []
    
    for i in range(year1, year2 + 1):
        for j in range(12):
#             Selecteer een specifieke maand in een jaar
            output_data = input_data.loc[input_data['mp_year'] == i]
            output_data = output_data.loc[output_data['mp_month'] == j + 1]
#         maak een nieuwe rij wanneer er data beschikbaar is
            if len(output_data['mp_price']) > 0:
#                 year
                year_list.append(i + (j / 12))

#                 country
                country_list.append(country)

#                 product
                product_list.append(product)
#                 average data            
                average_price_list.append(sum(output_data['mp_price']) / len(output_data['mp_price']))
            else:
                print('ERROR: Geen data beschikbaar over het jaar', i + j/12)
    
    output_data = pd.DataFrame()    
    output_data['country'] = country_list
    output_data['year'] = year_list
    output_data['product'] = product_list
    output_data['average_price'] = average_price_list
    return output_data

select_plot_foodprices_average(df_foodprices, 'Burkina Faso', 'Maize', 2004, 2006)
# Out:
#          country         year product  average_price
# 0   Burkina Faso  2004.000000   Maize      80.148290
# 1   Burkina Faso  2004.083333   Maize      80.776300
# 2   Burkina Faso  2004.166667   Maize      83.022422
# 3   Burkina Faso  2004.250000   Maize      85.010410
# 4   Burkina Faso  2004.333333   Maize      85.885000
# 5   Burkina Faso  2004.416667   Maize      85.694170
# 6   Burkina Faso  2004.500000   Maize      97.149560
# 7   Burkina Faso  2004.583333   Maize     105.256600
# 8   Burkina Faso  2004.666667   Maize     107.474650
# 9   Burkina Faso  2004.750000   Maize     118.147270
# 10  Burkina Faso  2004.833333   Maize     123.229800
# 11  Burkina Faso  2004.916667   Maize     127.271240
# 12  Burkina Faso  2005.000000   Maize     125.296809
# 13  Burkina Faso  2005.083333   Maize     131.122073
# 14  Burkina Faso  2005.166667   Maize     147.968264
# 15  Burkina Faso  2005.250000   Maize     170.912180
# 16  Burkina Faso  2005.333333   Maize     171.061930
# 17  Burkina Faso  2005.416667   Maize     216.184980
# 18  Burkina Faso  2005.500000   Maize     223.766390
# 19  Burkina Faso  2005.583333   Maize     216.561700
# 20  Burkina Faso  2005.666667   Maize     171.113282
# 21  Burkina Faso  2005.750000   Maize     131.132573
# 22  Burkina Faso  2005.833333   Maize     122.519300
# 23  Burkina Faso  2005.916667   Maize     126.645182
# 24  Burkina Faso  2006.000000   Maize     128.328730
# 25  Burkina Faso  2006.083333   Maize     124.282109
# 26  Burkina Faso  2006.166667   Maize     128.982727
# 27  Burkina Faso  2006.250000   Maize     136.047727
# 28  Burkina Faso  2006.333333   Maize     137.747209
# 29  Burkina Faso  2006.416667   Maize     132.427991
# 30  Burkina Faso  2006.500000   Maize     126.258900
# 31  Burkina Faso  2006.583333   Maize     115.898400
# 32  Burkina Faso  2006.666667   Maize     108.303500
# 33  Burkina Faso  2006.750000   Maize      95.959270
# 34  Burkina Faso  2006.833333   Maize      92.159830
# 35  Burkina Faso  2006.916667   Maize      91.860580

# %% [markdown]
# # Plot functies

# %%
from bokeh.plotting import figure
from bokeh.io import output_file, show, save
import pandas

def plot_line_difference(country, product, year1, year2):
    # Make sure x and y are of the same length.
    x1 = select_plot_foodprices_average(df_foodprices, country, product, 2004, 2014)['year'] 
    y1 = select_plot_foodprices_average(df_foodprices, country, product, 2004, 2014)['average_price']  

    x2 = select_plot_temperature_and_precipitation(df_weather, country, 2004, 2014)['YearMonth']    
    y2 = select_plot_temperature_and_precipitation(df_weather, country, 2004, 2014)['tas']    

#     output_file("Line.html")

    f = figure(plot_width=1500, plot_height=600)

    # Plot the line
    f.line(x1, y1, color='red')
    f.line(x2, y2, color='blue')

    show(f)

plot_line_difference('Mali', 'Maize', 2002, 2010)
# Out:
# ERROR: Geen data beschikbaar over het jaar 2012.9166666666667
# ERROR: Geen data beschikbaar over het jaar 2012.9166666666667

# %%
# laat zien welke producten er in een bepaald land te koop zijn
def products_country(input_data, country):
    products = []
    fp_country = input_data.loc[input_data['adm0_name'] == country]
    products_total = fp_country['cm_name']
    product_list = products_total.tolist()
    for item in product_list:
        if item not in products:
            products.append(item)
    return(products)
products_country(df_foodprices, 'Lebanon')
# Out:
# []
