# %%
import pandas as pd
import numpy as np
import os

print(os.getcwd())
# controleer altijd of je in de map helpfiles zit
# Out:
# C:\Users\boble\Documents\GitHub\DataProcessing\helpfiles

# %%
from select_df import select_df

df_foodprices = select_df(1, 'foodprices')
df_migration = select_df(1, 'migration_movements')
df_weather = select_df(1, 'temperature_and_precipitation')
# Out:
# Succesfully imported foodprices!
# Succesfully imported migration_movements!
# succesfully imported temperature_and_precipitation!

# %% [markdown]
# # Plot migration movements

# %%
def select_plot_migration_movements(input_data,origin, year1, year2):
    input_data = input_data.loc[input_data['Origin'] == origin]
    input_data = input_data.loc[(input_data['Timestamp'] > year1) & (input_data['Timestamp'] < year2)]
    return input_data

# %%
test = select_plot_migration_movements(df_migration, 'Zimbabwe', 1999, 2017)
test
# Out:
#         Origin    Timestamp  Value
# 37    Zimbabwe  1999.083333     31
# 100   Zimbabwe  1999.166667     38
# 114   Zimbabwe  1999.250000     48
# 165   Zimbabwe  1999.333333     45
# 187   Zimbabwe  1999.416667     38
# 213   Zimbabwe  1999.500000     34
# 266   Zimbabwe  1999.583333     42
# 297   Zimbabwe  1999.666667     46
# 331   Zimbabwe  1999.750000     35
# 343   Zimbabwe  1999.833333     43
# 390   Zimbabwe  1999.916667     63
# 435   Zimbabwe  2000.000000     85
# 449   Zimbabwe  2000.083333    128
# 485   Zimbabwe  2000.166667    126
# 525   Zimbabwe  2000.250000    130
# 545   Zimbabwe  2000.333333    196
# 611   Zimbabwe  2000.416667    185
# 629   Zimbabwe  2000.500000     72
# 654   Zimbabwe  2000.583333     10
# 697   Zimbabwe  2000.666667     12
# 718   Zimbabwe  2000.750000      8
# 780   Zimbabwe  2000.833333     12
# 801   Zimbabwe  2000.916667    158
# 825   Zimbabwe  2001.000000    305
# 882   Zimbabwe  2001.083333    324
# 895   Zimbabwe  2001.166667    297
# 949   Zimbabwe  2001.250000    286
# 976   Zimbabwe  2001.333333    307
# 990   Zimbabwe  2001.416667    308
# 1028  Zimbabwe  2001.500000    319
# ...        ...          ...    ...
# 6372  Zimbabwe  2014.583333    116
# 6383  Zimbabwe  2014.666667     98
# 6431  Zimbabwe  2014.750000     82
# 6442  Zimbabwe  2014.833333     70
# 6508  Zimbabwe  2014.916667     73
# 6528  Zimbabwe  2015.000000     97
# 6576  Zimbabwe  2015.083333    103
# 6605  Zimbabwe  2015.166667     84
# 6628  Zimbabwe  2015.250000     74
# 6654  Zimbabwe  2015.333333     75
# 6707  Zimbabwe  2015.416667     62
# 6727  Zimbabwe  2015.500000     63
# 6767  Zimbabwe  2015.583333     78
# 6788  Zimbabwe  2015.666667     98
# 6831  Zimbabwe  2015.750000     96
# 6861  Zimbabwe  2015.833333     84
# 6899  Zimbabwe  2015.916667     89
# 6948  Zimbabwe  2016.000000    103
# 6968  Zimbabwe  2016.083333     91
# 7001  Zimbabwe  2016.166667     81
# 7031  Zimbabwe  2016.250000     92
# 7058  Zimbabwe  2016.333333     92
# 7101  Zimbabwe  2016.416667    101
# 7132  Zimbabwe  2016.500000    144
# 7187  Zimbabwe  2016.583333    177
# 7222  Zimbabwe  2016.666667    157
# 7236  Zimbabwe  2016.750000    131
# 7270  Zimbabwe  2016.833333    143
# 7308  Zimbabwe  2016.916667    179
# 7340  Zimbabwe  2017.000000    164
#
# [216 rows x 3 columns]

# %% [markdown]
# # Plot temperature and precipitation

# %%
# geeft voor een #input_data van een #country de pr en tas vanaf #year1 tot en met #year2

def select_plot_temperature_and_precipitation(input_data, country, year1, year2):
    saved_dict = {'Mauritania': 'MRT', 'Lesotho': 'LSO', 'Somalia': 'SOM', 'Nigeria': 'NGA', 'Tanzania': 'TZA', 'Zambia': 'ZMB', 'Burundi': 'BDI', 'Afghanistan': 'AFG', 'Mali': 'MLI', 'Niger': 'NER', 'Malawi': 'MWI', 'Congo': 'ZAR', 'Cabo Verde': 'CPV', 'Sudan': 'SDN', 'Pakistan': 'PAK', 'Burkina Faso': 'BFA', 'Rwanda': 'RWA', 'Kenya': 'KEN', 'Senegal': 'SEN', 'Cameroon': 'CMR', 'Sierra Leone': 'SLE', 'Iraq': 'IRQ', 'Uganda': 'UGA', 'Mozambique': 'MOZ', 'Zimbabwe': 'ZWE', 'Central African Republic': 'CAF', 'Ethiopia': 'ETH', 'Guinea': 'GIN', 'Liberia': 'LBR', 'Djibouti': 'DJI', 'Iran': 'IRN', 'Madagascar': 'MDG', 'Lebanon': 'LBN'}

    if country in saved_dict.keys():
        country = saved_dict[country]
    else:
        print("Please enter correct country name")
    
    input_data = pd.DataFrame(input_data.loc[input_data['country'] == country])
    input_data = input_data.loc[(input_data['year'] > year1 - 1) & (input_data['year'] < year2 + 1)]
    
#     maak van de jaren en maanden kommajaren
    YearMonth = []
    month = []
    for row in input_data['month']:
        month.append(str(row))
        
    count = 0
    for year in input_data['year']:
        year = int(year) + (int(month[count])  - 1)/ 12
        YearMonth.append(year)
        count += 1
    input_data['YearMonth'] = YearMonth
    input_data = input_data[['pr', 'tas', 'country', 'YearMonth']]
    return input_data

select_plot_temperature_and_precipitation(df_weather, 'Lesotho', 1985, 2030)
# Out:
#              pr       tas country    YearMonth
# 6000  204.68800  18.64720     LSO  1991.000000
# 6001  124.99700  17.88130     LSO  1991.083333
# 6002  110.43400  15.83400     LSO  1991.166667
# 6003    3.49657  13.68640     LSO  1991.250000
# 6004    3.86758  10.60940     LSO  1991.333333
# 6005   13.04190   6.57098     LSO  1991.416667
# 6006    0.94483   7.48768     LSO  1991.500000
# 6007    3.26394   8.87845     LSO  1991.583333
# 6008   59.57440  13.14010     LSO  1991.666667
# 6009  154.31900  14.26600     LSO  1991.750000
# 6010   62.73080  15.83960     LSO  1991.833333
# 6011  124.43400  16.87680     LSO  1991.916667
# 6012   49.29210  19.62300     LSO  1992.000000
# 6013   57.49860  19.70280     LSO  1992.083333
# 6014   62.94090  17.33280     LSO  1992.166667
# 6015   20.05400  14.93980     LSO  1992.250000
# 6016    0.68631   9.65732     LSO  1992.333333
# 6017    0.44241   6.48702     LSO  1992.416667
# 6018    0.59084   7.15533     LSO  1992.500000
# 6019   44.59960   8.54639     LSO  1992.583333
# 6020    9.06036  13.96630     LSO  1992.666667
# 6021   69.61680  14.46120     LSO  1992.750000
# 6022  101.27500  15.19780     LSO  1992.833333
# 6023   63.34060  18.55760     LSO  1992.916667
# 6024   75.85950  19.70190     LSO  1993.000000
# 6025   99.88270  17.25200     LSO  1993.083333
# 6026   83.61760  16.52780     LSO  1993.166667
# 6027   49.64940  12.83620     LSO  1993.250000
# 6028   13.56430  10.22040     LSO  1993.333333
# 6029    3.70470   7.32104     LSO  1993.416667
# ...         ...       ...     ...          ...
# 6270    5.44050   8.85943     LSO  2013.500000
# 6271    4.86976   9.26293     LSO  2013.583333
# 6272    3.13513  13.47990     LSO  2013.666667
# 6273   62.14280  14.59120     LSO  2013.750000
# 6274   78.71600  16.64490     LSO  2013.833333
# 6275  188.62700  17.47640     LSO  2013.916667
# 6276   52.83950  20.12130     LSO  2014.000000
# 6277  199.34500  18.97260     LSO  2014.083333
# 6278   92.50900  16.70830     LSO  2014.166667
# 6279   34.03540  12.86790     LSO  2014.250000
# 6280   11.37930  10.58150     LSO  2014.333333
# 6281    2.39011   7.33333     LSO  2014.416667
# 6282    2.87602   7.68890     LSO  2014.500000
# 6283   13.77780  10.01210     LSO  2014.583333
# 6284    8.51619  13.88260     LSO  2014.666667
# 6285   31.47690  15.31350     LSO  2014.750000
# 6286  168.34100  15.56750     LSO  2014.833333
# 6287  115.96500  17.59910     LSO  2014.916667
# 6288   64.11730  19.14420     LSO  2015.000000
# 6289   54.89620  17.88450     LSO  2015.083333
# 6290   98.94550  17.37620     LSO  2015.166667
# 6291   25.89570  13.08760     LSO  2015.250000
# 6292    9.97749  11.13490     LSO  2015.333333
# 6293   36.81640   7.23080     LSO  2015.416667
# 6294   18.16340   7.80643     LSO  2015.500000
# 6295   14.76850   8.74273     LSO  2015.583333
# 6296   31.65650  13.30430     LSO  2015.666667
# 6297   35.01170  15.66440     LSO  2015.750000
# 6298   48.63930  15.77170     LSO  2015.833333
# 6299   29.61620  19.24540     LSO  2015.916667
#
# [300 rows x 4 columns]

# %%
df_foodprices
# Out:
#         Unnamed: 0  Unnamed: 0.1                    adm0_name adm1_name  \
# 0                0         24213                 Burkina Faso  Cascades
# 1                1         24214                 Burkina Faso  Cascades
# 2                2         24215                 Burkina Faso  Cascades
# 3                3         24216                 Burkina Faso  Cascades
# 4                4         24217                 Burkina Faso  Cascades
# 5                5         24218                 Burkina Faso  Cascades
# 6                6         24219                 Burkina Faso  Cascades
# 7                7         24220                 Burkina Faso  Cascades
# 8                8         24221                 Burkina Faso  Cascades
# 9                9         24222                 Burkina Faso  Cascades
# 10              10         24223                 Burkina Faso  Cascades
# 11              11         24224                 Burkina Faso  Cascades
# 12              12         24225                 Burkina Faso  Cascades
# 13              13         24226                 Burkina Faso  Cascades
# 14              14         24227                 Burkina Faso  Cascades
# 15              15         24228                 Burkina Faso  Cascades
# 16              16         24229                 Burkina Faso  Cascades
# 17              17         24230                 Burkina Faso  Cascades
# 18              18         24231                 Burkina Faso  Cascades
# 19              19         24232                 Burkina Faso  Cascades
# 20              20         24233                 Burkina Faso  Cascades
# 21              21         24234                 Burkina Faso  Cascades
# 22              22         24235                 Burkina Faso  Cascades
# 23              23         24236                 Burkina Faso  Cascades
# 24              24         24237                 Burkina Faso  Cascades
# 25              25         24238                 Burkina Faso  Cascades
# 26              26         24239                 Burkina Faso  Cascades
# 27              27         24240                 Burkina Faso  Cascades
# 28              28         24241                 Burkina Faso  Cascades
# 29              29         24242                 Burkina Faso  Cascades
# ...            ...           ...                          ...       ...
# 468361       60291        237261  Iran  (Islamic Republic of)    Tehran
# 468362       60292        237262  Iran  (Islamic Republic of)    Tehran
# 468363       60293        237263  Iran  (Islamic Republic of)    Tehran
# 468364       60294        237264  Iran  (Islamic Republic of)    Tehran
# 468365       60295        237265  Iran  (Islamic Republic of)    Tehran
# 468366       60296        237266  Iran  (Islamic Republic of)    Tehran
# 468367       60297        237267  Iran  (Islamic Republic of)    Tehran
# 468368       60298        237268  Iran  (Islamic Republic of)    Tehran
# 468369       60299        237269  Iran  (Islamic Republic of)    Tehran
# 468370       60300        237270  Iran  (Islamic Republic of)    Tehran
# 468371       60301        237271  Iran  (Islamic Republic of)    Tehran
# 468372       60302        237272  Iran  (Islamic Republic of)    Tehran
# 468373       60303        237273  Iran  (Islamic Republic of)    Tehran
# 468374       60304        237274  Iran  (Islamic Republic of)    Tehran
# 468375       60305        237275  Iran  (Islamic Republic of)    Tehran
# 468376       60306        237276  Iran  (Islamic Republic of)    Tehran
# 468377       60307        237277  Iran  (Islamic Republic of)    Tehran
# 468378       60308        237278  Iran  (Islamic Republic of)    Tehran
# 468379       60309        237279  Iran  (Islamic Republic of)    Tehran
# 468380       60310        237280  Iran  (Islamic Republic of)    Tehran
# 468381       60311        237281  Iran  (Islamic Republic of)    Tehran
# 468382       60312        237282  Iran  (Islamic Republic of)    Tehran
# 468383       60313        237283  Iran  (Islamic Republic of)    Tehran
# 468384       60314        237284  Iran  (Islamic Republic of)    Tehran
# 468385       60315        237285  Iran  (Islamic Republic of)    Tehran
# 468386       60316        237286  Iran  (Islamic Republic of)    Tehran
# 468387       60317        237287  Iran  (Islamic Republic of)    Tehran
# 468388       60318        237288  Iran  (Islamic Republic of)    Tehran
# 468389       60319        237289  Iran  (Islamic Republic of)    Tehran
# 468390       60320        237290  Iran  (Islamic Republic of)    Tehran
#
#              mkt_name  cm_name cur_name pt_name  um_id um_name  mp_month  \
# 0             Banfora    Maize      XOF  Retail      5      KG         1
# 1             Banfora    Maize      XOF  Retail      5      KG         2
# 2             Banfora    Maize      XOF  Retail      5      KG         3
# 3             Banfora    Maize      XOF  Retail      5      KG         4
# 4             Banfora    Maize      XOF  Retail      5      KG         5
# 5             Banfora    Maize      XOF  Retail      5      KG         6
# 6             Banfora    Maize      XOF  Retail      5      KG         7
# 7             Banfora    Maize      XOF  Retail      5      KG         8
# 8             Banfora    Maize      XOF  Retail      5      KG         9
# 9             Banfora    Maize      XOF  Retail      5      KG        10
# 10            Banfora    Maize      XOF  Retail      5      KG        11
# 11            Banfora    Maize      XOF  Retail      5      KG        12
# 12            Banfora    Maize      XOF  Retail      5      KG         1
# 13            Banfora    Maize      XOF  Retail      5      KG         2
# 14            Banfora    Maize      XOF  Retail      5      KG         3
# 15            Banfora    Maize      XOF  Retail      5      KG         4
# 16            Banfora    Maize      XOF  Retail      5      KG         5
# 17            Banfora    Maize      XOF  Retail      5      KG         6
# 18            Banfora    Maize      XOF  Retail      5      KG         7
# 19            Banfora    Maize      XOF  Retail      5      KG         8
# 20            Banfora    Maize      XOF  Retail      5      KG         9
# 21            Banfora    Maize      XOF  Retail      5      KG        10
# 22            Banfora    Maize      XOF  Retail      5      KG        11
# 23            Banfora    Maize      XOF  Retail      5      KG        12
# 24            Banfora    Maize      XOF  Retail      5      KG         1
# 25            Banfora    Maize      XOF  Retail      5      KG         2
# 26            Banfora    Maize      XOF  Retail      5      KG         3
# 27            Banfora    Maize      XOF  Retail      5      KG         4
# 28            Banfora    Maize      XOF  Retail      5      KG         5
# 29            Banfora    Maize      XOF  Retail      5      KG         6
# ...               ...      ...      ...     ...    ...     ...       ...
# 468361  Tehran Market  Lentils      IRR  Retail      5      KG         4
# 468362  Tehran Market  Lentils      IRR  Retail      5      KG         5
# 468363  Tehran Market  Lentils      IRR  Retail      5      KG         6
# 468364  Tehran Market  Lentils      IRR  Retail      5      KG         7
# 468365  Tehran Market  Lentils      IRR  Retail      5      KG         8
# 468366  Tehran Market  Lentils      IRR  Retail      5      KG         9
# 468367  Tehran Market  Lentils      IRR  Retail      5      KG        10
# 468368  Tehran Market  Lentils      IRR  Retail      5      KG        11
# 468369  Tehran Market  Lentils      IRR  Retail      5      KG        12
# 468370  Tehran Market  Lentils      IRR  Retail      5      KG         1
# 468371  Tehran Market  Lentils      IRR  Retail      5      KG         2
# 468372  Tehran Market  Lentils      IRR  Retail      5      KG         3
# 468373  Tehran Market  Lentils      IRR  Retail      5      KG         4
# 468374  Tehran Market  Lentils      IRR  Retail      5      KG         5
# 468375  Tehran Market  Lentils      IRR  Retail      5      KG         6
# 468376  Tehran Market  Lentils      IRR  Retail      5      KG         7
# 468377  Tehran Market  Lentils      IRR  Retail      5      KG         8
# 468378  Tehran Market  Lentils      IRR  Retail      5      KG         9
# 468379  Tehran Market  Lentils      IRR  Retail      5      KG        10
# 468380  Tehran Market  Lentils      IRR  Retail      5      KG        11
# 468381  Tehran Market  Lentils      IRR  Retail      5      KG        12
# 468382  Tehran Market  Lentils      IRR  Retail      5      KG         1
# 468383  Tehran Market  Lentils      IRR  Retail      5      KG         2
# 468384  Tehran Market  Lentils      IRR  Retail      5      KG         3
# 468385  Tehran Market  Lentils      IRR  Retail      5      KG         4
# 468386  Tehran Market  Lentils      IRR  Retail      5      KG         5
# 468387  Tehran Market  Lentils      IRR  Retail      5      KG         6
# 468388  Tehran Market  Lentils      IRR  Retail      5      KG         7
# 468389  Tehran Market  Lentils      IRR  Retail      5      KG         8
# 468390  Tehran Market  Lentils      IRR  Retail      5      KG         9
#
#         mp_year     mp_price         Year
# 0          2003     105.6558  2003.000000
# 1          2003     103.3953  2003.083333
# 2          2003     101.8303  2003.166667
# 3          2003     103.3039  2003.250000
# 4          2003     103.7575  2003.333333
# 5          2003     102.4965  2003.416667
# 6          2003      82.3070  2003.500000
# 7          2003      76.6009  2003.583333
# 8          2003      71.1824  2003.666667
# 9          2003      53.1701  2003.750000
# 10         2003      52.2340  2003.833333
# 11         2003      50.2570  2003.916667
# 12         2004      50.3069  2004.000000
# 13         2004      48.0672  2004.083333
# 14         2004      51.7204  2004.166667
# 15         2004      59.2121  2004.250000
# 16         2004      62.8178  2004.333333
# 17         2004      62.4239  2004.416667
# 18         2004      73.8951  2004.500000
# 19         2004      75.1852  2004.583333
# 20         2004      87.9618  2004.666667
# 21         2004      92.6165  2004.750000
# 22         2004      88.9691  2004.833333
# 23         2004      86.4592  2004.916667
# 24         2005      86.6973  2005.000000
# 25         2005     114.4360  2005.083333
# 26         2005     141.3891  2005.166667
# 27         2005     149.0165  2005.250000
# 28         2005     158.8906  2005.333333
# 29         2005     200.3926  2005.416667
# ...         ...          ...          ...
# 468361     2015   65630.0000  2015.250000
# 468362     2015   53050.0000  2015.333333
# 468363     2015   75930.0000  2015.416667
# 468364     2015   77600.0000  2015.500000
# 468365     2015   79690.0000  2015.583333
# 468366     2015   79660.0000  2015.666667
# 468367     2015   80220.0000  2015.750000
# 468368     2015   89370.0000  2015.833333
# 468369     2015   87800.0000  2015.916667
# 468370     2016   89050.0000  2016.000000
# 468371     2016   94610.0000  2016.083333
# 468372     2016   93770.0000  2016.166667
# 468373     2016   94110.0000  2016.250000
# 468374     2016   94760.0000  2016.333333
# 468375     2016   93510.0000  2016.416667
# 468376     2016   90270.0000  2016.500000
# 468377     2016   93940.0000  2016.583333
# 468378     2016   93980.0000  2016.666667
# 468379     2016   93810.0000  2016.750000
# 468380     2016   95460.0000  2016.833333
# 468381     2016   96230.0000  2016.916667
# 468382     2017   97630.0000  2017.000000
# 468383     2017   96490.0000  2017.083333
# 468384     2017  116810.0000  2017.166667
# 468385     2017   96500.0000  2017.250000
# 468386     2017   99800.0000  2017.333333
# 468387     2017   98950.0000  2017.416667
# 468388     2017   98070.0000  2017.500000
# 468389     2017   97900.0000  2017.583333
# 468390     2017   97900.0000  2017.666667
#
# [468391 rows x 14 columns]

# %% [markdown]
# # Plot foodprices per market

# %%
def select_plot_foodprices_per_market(input_data, country, product, year1, year2):
    input_data = input_data.loc[input_data['adm0_name'] == country]
    input_data = input_data.loc[input_data['cm_name'] == product]
    input_data = input_data.loc[(input_data['Year'] >= year1) & (input_data['Year'] < year2 + 1)]
    return input_data

select_plot_foodprices_per_market(df_foodprices, 'Zimbabwe', 'Cowpeas', 1990, 2020)
# Out:
#         Unnamed: 0  Unnamed: 0.1 adm0_name   adm1_name mkt_name  cm_name  \
# 405651      405651        762716  Zimbabwe      Harare    Mbare  Cowpeas
# 405652      405652        762717  Zimbabwe      Harare    Mbare  Cowpeas
# 405653      405653        762718  Zimbabwe      Harare    Mbare  Cowpeas
# 405654      405654        762719  Zimbabwe      Harare    Mbare  Cowpeas
# 405655      405655        762720  Zimbabwe      Harare    Mbare  Cowpeas
# 405656      405656        762721  Zimbabwe      Harare    Mbare  Cowpeas
# 405657      405657        762722  Zimbabwe      Harare    Mbare  Cowpeas
# 405658      405658        762723  Zimbabwe      Harare    Mbare  Cowpeas
# 405659      405659        762724  Zimbabwe      Harare    Mbare  Cowpeas
# 405660      405660        762725  Zimbabwe      Harare    Mbare  Cowpeas
# 405661      405661        762726  Zimbabwe      Harare    Mbare  Cowpeas
# 405662      405662        762727  Zimbabwe      Harare    Mbare  Cowpeas
# 405663      405663        762728  Zimbabwe      Harare    Mbare  Cowpeas
# 405664      405664        762729  Zimbabwe      Harare    Mbare  Cowpeas
# 405665      405665        762730  Zimbabwe      Harare    Mbare  Cowpeas
# 405666      405666        762731  Zimbabwe      Harare    Mbare  Cowpeas
# 405667      405667        762732  Zimbabwe      Harare    Mbare  Cowpeas
# 405668      405668        762733  Zimbabwe      Harare    Mbare  Cowpeas
# 405669      405669        762734  Zimbabwe      Harare    Mbare  Cowpeas
# 405670      405670        762735  Zimbabwe      Harare    Mbare  Cowpeas
# 405671      405671        762736  Zimbabwe      Harare    Mbare  Cowpeas
# 405672      405672        762737  Zimbabwe      Harare    Mbare  Cowpeas
# 406647      406647        763712  Zimbabwe    Masvingo  Mucheke  Cowpeas
# 406648      406648        763713  Zimbabwe    Masvingo  Mucheke  Cowpeas
# 406649      406649        763714  Zimbabwe    Masvingo  Mucheke  Cowpeas
# 406650      406650        763715  Zimbabwe    Masvingo  Mucheke  Cowpeas
# 406651      406651        763716  Zimbabwe    Masvingo  Mucheke  Cowpeas
# 406652      406652        763717  Zimbabwe    Masvingo  Mucheke  Cowpeas
# 406653      406653        763718  Zimbabwe    Masvingo  Mucheke  Cowpeas
# 406654      406654        763719  Zimbabwe    Masvingo  Mucheke  Cowpeas
# 407099      407099        764164  Zimbabwe  Manicaland  Sakubva  Cowpeas
# 407100      407100        764165  Zimbabwe  Manicaland  Sakubva  Cowpeas
# 407101      407101        764166  Zimbabwe  Manicaland  Sakubva  Cowpeas
# 407102      407102        764167  Zimbabwe  Manicaland  Sakubva  Cowpeas
# 407103      407103        764168  Zimbabwe  Manicaland  Sakubva  Cowpeas
# 407104      407104        764169  Zimbabwe  Manicaland  Sakubva  Cowpeas
#
#        cur_name pt_name  um_id um_name  mp_month  mp_year  mp_price  \
# 405651      USD  Retail      5      KG         8     2014      1.00
# 405652      USD  Retail      5      KG        10     2014      1.00
# 405653      USD  Retail      5      KG        11     2014      1.00
# 405654      USD  Retail      5      KG         4     2015      0.57
# 405655      USD  Retail      5      KG         5     2015      0.57
# 405656      USD  Retail      5      KG         6     2015      0.57
# 405657      USD  Retail      5      KG         7     2015      0.75
# 405658      USD  Retail      5      KG         8     2015      0.75
# 405659      USD  Retail      5      KG         9     2015      0.75
# 405660      USD  Retail      5      KG        10     2015      0.75
# 405661      USD  Retail      5      KG        11     2015      0.70
# 405662      USD  Retail      5      KG        12     2015      0.70
# 405663      USD  Retail      5      KG         1     2016      0.70
# 405664      USD  Retail      5      KG         2     2016      0.70
# 405665      USD  Retail      5      KG         8     2016      0.75
# 405666      USD  Retail      5      KG         1     2017      0.90
# 405667      USD  Retail      5      KG         2     2017      1.70
# 405668      USD  Retail      5      KG         3     2017      1.70
# 405669      USD  Retail      5      KG         4     2017      1.70
# 405670      USD  Retail      5      KG         5     2017      1.70
# 405671      USD  Retail      5      KG         6     2017      0.45
# 405672      USD  Retail      5      KG         7     2017      0.45
# 406647      USD  Retail      5      KG         8     2014      0.86
# 406648      USD  Retail      5      KG        10     2014      0.70
# 406649      USD  Retail      5      KG         1     2017      0.85
# 406650      USD  Retail      5      KG         2     2017      0.85
# 406651      USD  Retail      5      KG         3     2017      0.85
# 406652      USD  Retail      5      KG         4     2017      0.85
# 406653      USD  Retail      5      KG         5     2017      0.85
# 406654      USD  Retail      5      KG         6     2017      0.57
# 407099      USD  Retail      5      KG         8     2014      2.00
# 407100      USD  Retail      5      KG         1     2017      1.00
# 407101      USD  Retail      5      KG         2     2017      1.00
# 407102      USD  Retail      5      KG         3     2017      1.00
# 407103      USD  Retail      5      KG         4     2017      1.00
# 407104      USD  Retail      5      KG         5     2017      1.00
#
#                Year
# 405651  2014.583333
# 405652  2014.750000
# 405653  2014.833333
# 405654  2015.250000
# 405655  2015.333333
# 405656  2015.416667
# 405657  2015.500000
# 405658  2015.583333
# 405659  2015.666667
# 405660  2015.750000
# 405661  2015.833333
# 405662  2015.916667
# 405663  2016.000000
# 405664  2016.083333
# 405665  2016.583333
# 405666  2017.000000
# 405667  2017.083333
# 405668  2017.166667
# 405669  2017.250000
# 405670  2017.333333
# 405671  2017.416667
# 405672  2017.500000
# 406647  2014.583333
# 406648  2014.750000
# 406649  2017.000000
# 406650  2017.083333
# 406651  2017.166667
# 406652  2017.250000
# 406653  2017.333333
# 406654  2017.416667
# 407099  2014.583333
# 407100  2017.000000
# 407101  2017.083333
# 407102  2017.166667
# 407103  2017.250000
# 407104  2017.333333

# %%
# 

def select_plot_foodprices_average(input_data, country, product, year1, year2):
    input_data = select_plot_foodprices_per_market(input_data, country, product, year1, year2)
    
    country_list = []
    product_list = []
    average_price_list = []
    year_list = []
    
    for i in range(year1, year2 + 1):
        for j in range(12):
#             Selecteer een specifieke maand in een jaar
            output_data = input_data.loc[input_data['mp_year'] == i]
            output_data = output_data.loc[output_data['mp_month'] == j + 1]
#         maak een nieuwe rij wanneer er data beschikbaar is
            if len(output_data['mp_price']) > 0:
#                 year
                year_list.append(i + (j / 12))

#                 country
                country_list.append(country)

#                 product
                product_list.append(product)
#                 average data            
                average_price_list.append(sum(output_data['mp_price']) / len(output_data['mp_price']))

    
    output_data = pd.DataFrame()    
    output_data['country'] = country_list
    output_data['year'] = year_list
    output_data['product'] = product_list
    output_data['average_price'] = average_price_list
    return output_data

select_plot_foodprices_average(df_foodprices, 'Zimbabwe', 'Cowpeas', 1998, 2018)
# Out:
#      country         year  product  average_price
# 0   Zimbabwe  2014.583333  Cowpeas       1.286667
# 1   Zimbabwe  2014.750000  Cowpeas       0.850000
# 2   Zimbabwe  2014.833333  Cowpeas       1.000000
# 3   Zimbabwe  2015.250000  Cowpeas       0.570000
# 4   Zimbabwe  2015.333333  Cowpeas       0.570000
# 5   Zimbabwe  2015.416667  Cowpeas       0.570000
# 6   Zimbabwe  2015.500000  Cowpeas       0.750000
# 7   Zimbabwe  2015.583333  Cowpeas       0.750000
# 8   Zimbabwe  2015.666667  Cowpeas       0.750000
# 9   Zimbabwe  2015.750000  Cowpeas       0.750000
# 10  Zimbabwe  2015.833333  Cowpeas       0.700000
# 11  Zimbabwe  2015.916667  Cowpeas       0.700000
# 12  Zimbabwe  2016.000000  Cowpeas       0.700000
# 13  Zimbabwe  2016.083333  Cowpeas       0.700000
# 14  Zimbabwe  2016.583333  Cowpeas       0.750000
# 15  Zimbabwe  2017.000000  Cowpeas       0.916667
# 16  Zimbabwe  2017.083333  Cowpeas       1.183333
# 17  Zimbabwe  2017.166667  Cowpeas       1.183333
# 18  Zimbabwe  2017.250000  Cowpeas       1.183333
# 19  Zimbabwe  2017.333333  Cowpeas       1.183333
# 20  Zimbabwe  2017.416667  Cowpeas       0.510000
# 21  Zimbabwe  2017.500000  Cowpeas       0.450000

# %%
def normalize(input_data, column):
    values = []
    
    input_data[column]
    for value in input_data[column]:
         values.append(value)
            
    Min = min(values)
    Max = max(values)
        
    output_data = []
    for value in input_data[column]:
        output_data.append((value - Min)/(Max - Min))
    
    input_data['Normalized_data'] = output_data
    
    return input_data

# %%
def possible_range(data1, data2):
    # bepaal de range van dataset 1 (migration movements)
    min1 = float(data1.head(1))
    max1 = float(data1.tail(1))
    # bepaal de range van dataset 2 (foodprices average)
    min2 = float(data2.head(1))
    max2 = float(data2.tail(1))

    # bepaal de mogelijke combinatie range
    if min1 >= min2: year_min = int(np.ceil(min1))
    else: year_min = int(np.ceil(min2))
    if max1 <= max2: year_max = int(np.ceil(max1))
    else: year_max = int(np.ceil(max1))
        
    return(year_min, year_max)

# werking
# data1 = select_plot_migration_movements1(df_migration, 'Zimbabwe', 1990, 2018)['Timestamp']
# data2 = select_plot_foodprices_average(df_foodprices, 'Zimbabwe', 'Cowpeas', 1990, 2018)['year']
# possible_range(data1, data2)

# %% [markdown]
# # Plot functies

# %%
from bokeh.plotting import figure
from bokeh.io import output_file, show, save

import pandas

# Make sure x and y are of the same length.
x1 = select_plot_foodprices_average(df_foodprices, 'Lesotho', 'Beans (sugar-red)', 2004, 2014)['year'] 
y1 = normalize(select_plot_foodprices_average(df_foodprices, 'Lesotho', 'Beans (sugar-red)', 2004, 2014), 'average_price')['Normalized_data']  

x2 = select_plot_temperature_and_precipitation(df_weather, 'Lesotho', 2004, 2014)['YearMonth']    
y2 = normalize(select_plot_temperature_and_precipitation(df_weather, 'Lesotho', 2004, 2014), 'tas')['Normalized_data']    

output_file("Line.html")

f = figure(plot_width=1500, plot_height=600)

# Plot the line
f.line(x1, y1, color='red')
f.line(x2, y2, color='blue')

show(f)

# %%
df
# Out:
#         Unnamed: 0  Unnamed: 0.1 adm0_name            adm1_name  \
# 405420      405420        762485  Zimbabwe               Harare
# 405421      405421        762486  Zimbabwe               Harare
# 405422      405422        762487  Zimbabwe               Harare
# 405423      405423        762488  Zimbabwe               Harare
# 405424      405424        762489  Zimbabwe               Harare
# 405425      405425        762490  Zimbabwe               Harare
# 405426      405426        762491  Zimbabwe               Harare
# 405427      405427        762492  Zimbabwe               Harare
# 405428      405428        762493  Zimbabwe               Harare
# 405429      405429        762494  Zimbabwe               Harare
# 405430      405430        762495  Zimbabwe               Harare
# 405431      405431        762496  Zimbabwe               Harare
# 405432      405432        762497  Zimbabwe               Harare
# 405433      405433        762498  Zimbabwe               Harare
# 405434      405434        762499  Zimbabwe               Harare
# 405435      405435        762500  Zimbabwe               Harare
# 405436      405436        762501  Zimbabwe               Harare
# 405437      405437        762502  Zimbabwe               Harare
# 405438      405438        762503  Zimbabwe               Harare
# 405439      405439        762504  Zimbabwe               Harare
# 405440      405440        762505  Zimbabwe               Harare
# 405441      405441        762506  Zimbabwe               Harare
# 405442      405442        762507  Zimbabwe               Harare
# 405443      405443        762508  Zimbabwe               Harare
# 405444      405444        762509  Zimbabwe               Harare
# 405445      405445        762510  Zimbabwe               Harare
# 405446      405446        762511  Zimbabwe               Harare
# 405447      405447        762512  Zimbabwe               Harare
# 405448      405448        762513  Zimbabwe               Harare
# 405449      405449        762514  Zimbabwe               Harare
# ...            ...           ...       ...                  ...
# 407824      407824        764889  Zimbabwe   Matabeleland South
# 407825      407825        764890  Zimbabwe   Matabeleland South
# 407840      407840        764905  Zimbabwe   Matabeleland South
# 407841      407841        764906  Zimbabwe   Matabeleland South
# 407854      407854        764919  Zimbabwe   Matabeleland South
# 407862      407862        764927  Zimbabwe   Matabeleland South
# 407870      407870        764935  Zimbabwe   Matabeleland South
# 407885      407885        764950  Zimbabwe             Masvingo
# 407886      407886        764951  Zimbabwe             Masvingo
# 407887      407887        764952  Zimbabwe             Masvingo
# 407905      407905        764970  Zimbabwe             Masvingo
# 407906      407906        764971  Zimbabwe             Masvingo
# 407920      407920        764985  Zimbabwe     Mashonaland East
# 407921      407921        764986  Zimbabwe     Mashonaland East
# 407922      407922        764987  Zimbabwe     Mashonaland East
# 407949      407949        765014  Zimbabwe     Mashonaland East
# 407974      407974        765039  Zimbabwe  Mashonaland Central
# 407975      407975        765040  Zimbabwe  Mashonaland Central
# 407976      407976        765041  Zimbabwe  Mashonaland Central
# 408001      408001        765066  Zimbabwe  Mashonaland Central
# 408002      408002        765067  Zimbabwe  Mashonaland Central
# 408003      408003        765068  Zimbabwe  Mashonaland Central
# 408023      408023        765088  Zimbabwe             Midlands
# 408029      408029        765094  Zimbabwe             Midlands
# 408040      408040        765105  Zimbabwe     Mashonaland West
# 408041      408041        765106  Zimbabwe     Mashonaland West
# 408047      408047        765112  Zimbabwe     Mashonaland West
# 408057      408057        765122  Zimbabwe     Mashonaland West
# 408058      408058        765123  Zimbabwe     Mashonaland West
# 408059      408059        765124  Zimbabwe     Mashonaland West
#
#                        mkt_name cm_name cur_name pt_name  um_id um_name  \
# 405420                    Mbare   Maize      USD  Retail      5      KG
# 405421                    Mbare   Maize      USD  Retail      5      KG
# 405422                    Mbare   Maize      USD  Retail      5      KG
# 405423                    Mbare   Maize      USD  Retail      5      KG
# 405424                    Mbare   Maize      USD  Retail      5      KG
# 405425                    Mbare   Maize      USD  Retail      5      KG
# 405426                    Mbare   Maize      USD  Retail      5      KG
# 405427                    Mbare   Maize      USD  Retail      5      KG
# 405428                    Mbare   Maize      USD  Retail      5      KG
# 405429                    Mbare   Maize      USD  Retail      5      KG
# 405430                    Mbare   Maize      USD  Retail      5      KG
# 405431                    Mbare   Maize      USD  Retail      5      KG
# 405432                    Mbare   Maize      USD  Retail      5      KG
# 405433                    Mbare   Maize      USD  Retail      5      KG
# 405434                    Mbare   Maize      USD  Retail      5      KG
# 405435                    Mbare   Maize      USD  Retail      5      KG
# 405436                    Mbare   Maize      USD  Retail      5      KG
# 405437                    Mbare   Maize      USD  Retail      5      KG
# 405438                    Mbare   Maize      USD  Retail      5      KG
# 405439                    Mbare   Maize      USD  Retail      5      KG
# 405440                    Mbare   Maize      USD  Retail      5      KG
# 405441                    Mbare   Maize      USD  Retail      5      KG
# 405442                    Mbare   Maize      USD  Retail      5      KG
# 405443                    Mbare   Maize      USD  Retail      5      KG
# 405444                    Mbare   Maize      USD  Retail      5      KG
# 405445                    Mbare   Maize      USD  Retail      5      KG
# 405446                    Mbare   Maize      USD  Retail      5      KG
# 405447                    Mbare   Maize      USD  Retail      5      KG
# 405448                    Mbare   Maize      USD  Retail      5      KG
# 405449                    Mbare   Maize      USD  Retail      5      KG
# ...                         ...     ...      ...     ...    ...     ...
# 407824                  Mambale   Maize      USD  Retail      5      KG
# 407825                  Mambale   Maize      USD  Retail      5      KG
# 407840                  Maphisa   Maize      USD  Retail      5      KG
# 407841                  Maphisa   Maize      USD  Retail      5      KG
# 407854                     Kezi   Maize      USD  Retail      5      KG
# 407862             Tshelanyemba   Maize      USD  Retail      5      KG
# 407870             Saint Joseph   Maize      USD  Retail      5      KG
# 407885                  Neshuro   Maize      USD  Retail      5      KG
# 407886                  Neshuro   Maize      USD  Retail      5      KG
# 407887                  Neshuro   Maize      USD  Retail      5      KG
# 407905                 Sarahuro   Maize      USD  Retail      5      KG
# 407906                 Sarahuro   Maize      USD  Retail      5      KG
# 407920                    Kotwa   Maize      USD  Retail      5      KG
# 407921                    Kotwa   Maize      USD  Retail      5      KG
# 407922                    Kotwa   Maize      USD  Retail      5      KG
# 407949                   Makaha   Maize      USD  Retail      5      KG
# 407974                 Rushinga   Maize      USD  Retail      5      KG
# 407975                 Rushinga   Maize      USD  Retail      5      KG
# 407976                 Rushinga   Maize      USD  Retail      5      KG
# 408001                Chimhanda   Maize      USD  Retail      5      KG
# 408002                Chimhanda   Maize      USD  Retail      5      KG
# 408003                Chimhanda   Maize      USD  Retail      5      KG
# 408023                   Mabasa   Maize      USD  Retail      5      KG
# 408029                   Vhugwi   Maize      USD  Retail      5      KG
# 408040  Negande business centre   Maize      USD  Retail      5      KG
# 408041  Negande business centre   Maize      USD  Retail      5      KG
# 408047                 Kasvisva   Maize      USD  Retail      5      KG
# 408057                     Mola   Maize      USD  Retail      5      KG
# 408058                     Mola   Maize      USD  Retail      5      KG
# 408059                     Mola   Maize      USD  Retail      5      KG
#
#         mp_month  mp_year  mp_price         Year
# 405420         1     2010    0.3143  2010.000000
# 405421         2     2010    0.3429  2010.083333
# 405422         3     2010    0.3143  2010.166667
# 405423         4     2010    0.2857  2010.250000
# 405424         5     2010    0.2286  2010.333333
# 405425         6     2010    0.2286  2010.416667
# 405426         7     2010    0.2286  2010.500000
# 405427         8     2010    0.2286  2010.583333
# 405428         9     2010    0.2286  2010.666667
# 405429        10     2010    0.2286  2010.750000
# 405430        11     2010    0.2286  2010.833333
# 405431        12     2010    0.2857  2010.916667
# 405432         1     2011    0.3429  2011.000000
# 405433         2     2011    0.3429  2011.083333
# 405434         3     2011    0.3429  2011.166667
# 405435         4     2011    0.3429  2011.250000
# 405436         5     2011    0.2857  2011.333333
# 405437         6     2011    0.2857  2011.416667
# 405438         7     2011    0.2857  2011.500000
# 405439         8     2011    0.2857  2011.583333
# 405440         9     2011    0.2857  2011.666667
# 405441        10     2011    0.2900  2011.750000
# 405442        11     2011    0.2900  2011.833333
# 405443        12     2011    0.2900  2011.916667
# 405444         1     2012    0.3400  2012.000000
# 405445         2     2012    0.3400  2012.083333
# 405446         3     2012    0.3400  2012.166667
# 405447         4     2012    0.2900  2012.250000
# 405448         5     2012    0.2900  2012.333333
# 405449         6     2012    0.2900  2012.416667
# ...          ...      ...       ...          ...
# 407824        10     2017    0.5700  2017.750000
# 407825        11     2017    0.5700  2017.833333
# 407840         8     2017    0.4000  2017.583333
# 407841         9     2017    0.4000  2017.666667
# 407854         9     2017    0.4500  2017.666667
# 407862         9     2017    0.3100  2017.666667
# 407870         9     2017    0.4000  2017.666667
# 407885         8     2017    0.2900  2017.583333
# 407886         9     2017    0.2900  2017.666667
# 407887        10     2017    0.2900  2017.750000
# 407905         9     2017    0.2900  2017.666667
# 407906        10     2017    0.2900  2017.750000
# 407920         8     2017    0.2900  2017.583333
# 407921         9     2017    0.2900  2017.666667
# 407922        10     2017    0.2900  2017.750000
# 407949        10     2017    0.1700  2017.750000
# 407974         8     2017    0.2000  2017.583333
# 407975         9     2017    0.2000  2017.666667
# 407976        10     2017    0.1700  2017.750000
# 408001         8     2017    0.2000  2017.583333
# 408002         9     2017    0.2000  2017.666667
# 408003        10     2017    0.1700  2017.750000
# 408023         9     2017    0.2000  2017.666667
# 408029         9     2017    0.2300  2017.666667
# 408040         9     2017    0.2900  2017.666667
# 408041        10     2017    0.4000  2017.750000
# 408047        10     2017    0.1700  2017.750000
# 408057         8     2017    0.2900  2017.583333
# 408058         9     2017    0.2900  2017.666667
# 408059        10     2017    0.2300  2017.750000
#
# [1365 rows x 14 columns]

# %%
country = 'Guinea'
product = 'Rice (local)'

df = select_plot_foodprices_per_market(df_foodprices, country, product, 1990, 2020)

f = figure(plot_width=800, plot_height=300)

# gemiddelde voedselprijzen
x2 = select_plot_foodprices_average(df_foodprices, country, product, 1990, 2020)['year']
y2 = select_plot_foodprices_average(df_foodprices, country, product, 1990, 2020)['average_price']
    
# foodprices per markt
for product in df.mkt_name.unique():
    df_market = df.loc[df.mkt_name == df.mkt_name.unique()[0]]

    x1 = df['Year'] 
    y1 = df['mp_price']

    f.scatter(x1, y1, color='lightgrey', size=5, legend="Individual market prices")
    
# design
f.title.text="Correlation between {} and refugees in {}".format(product, country)
f.xaxis.axis_label = "year"
f.yaxis.axis_label = "Migration movements"
f.legend.location = "top_left"

f.line(x2, y2, color='red', legend="Average foodprice")

show(f)
# Out:
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='4038e748-7a23-4495-b7e0-56c4c7bbc7ee', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='771bed5f-a739-4ad3-b63d-e35ede2f31fc', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='9eeb67d1-98e3-4b8c-8ef8-760dd8d61e01', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='c22f9411-b3c2-4ec5-b2f9-43917a843bdb', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='d0954324-a58e-41ae-8081-d079b701e61c', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='d4787401-53ba-47d7-a3ad-e26b18104d09', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='ee15c6e0-0c98-4981-b235-987a7f4df2e7', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='f43602dc-6ecd-4a0e-af51-3a0d6ac52686', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='02bff6d3-4495-4cd3-b3ac-b102c825c073', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='0712afbe-fceb-4b26-a841-39617b3a22a7', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='0e94d68e-b2b5-41e1-b94c-cb6e0721d5a9', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='0f48467f-968b-4dcd-af55-7eb06a467b2a', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='29e52869-fedf-4b55-9f8b-9bcf42a7c7a3', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='33b782b3-d1e6-44d9-8991-a9fd07e5127f', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='3877ba84-1ed3-4475-834f-bc2ce811aef3', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='3c7ec845-7873-4931-8fd4-4f9d0d3e7152', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='487a0586-a488-4174-a450-b1f8b0927863', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='4f58159b-934f-4a57-94cd-3e8ad3134d6d', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='5fa7d535-8615-49f2-bedd-055421d14ba7', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='6701508e-7369-4a4e-aaac-094b266b4185', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='7fc6d3ff-fc61-42e4-b66e-a6ceb86fcd2b', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='9b80f97d-a187-40c2-b471-d8b744c7a401', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='9dab0760-3a22-430e-a7da-702846d061ee', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='a8d5fc0b-d973-49d5-8329-6701835f62fd', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='b8ee28cb-b5ea-428f-9627-68dfd628c0b4', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='bd504c9e-0db0-4d8a-a80f-9b94d5204ddd', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='cf323e81-eda0-4b4b-84e0-ef862847378b', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='d4507cc0-8894-40b4-925a-90fd66611337', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='fd5eddd9-261b-46ac-bd43-622585a63871', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='0887dcbe-f23d-4a52-b7d8-e799a5583b31', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='0e5a6c78-bb87-4b77-bc53-60959fd25f44', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='1dd163d7-96a1-4ad7-8b50-b742f3fb7801', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='24fbcd60-5264-4a05-860a-d40d46e4dcc7', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='2d02a217-2379-4351-999e-066fe6c7d19b', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='320c46d5-5670-42f9-aec5-5108192d7954', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='4590fbc1-3fe2-42a5-bbb7-7be211c42d59', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='476bbe7f-78a9-4425-adcc-ecd959b5def7', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='5cc7931b-0b98-42f3-a13c-d90080eb1888', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='6b3b982a-6477-49f4-9d2e-558735cbb76b', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='6fe3a7f4-a8cd-4939-9e50-09679b863a67', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='76f67c5f-d1cc-4311-a944-7e3c175b6a75', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='97fd2469-2898-4385-ab6b-6fe2e29fe3bc', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='9b9b37a9-6e4e-4813-bdc2-af9330dd99b4', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='9ed2d446-93ef-476a-9ece-b3baed2dbaa3', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='b6d67c0a-e267-4f60-87a6-4dcb2863e593', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='c820cf72-a81b-45fc-95bb-52bf2fb036f0', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='dcdcf383-59e1-431f-be9b-2274afc6dc00', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='dd341d53-2b59-4823-93de-003d9ef5b9e6', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='e8db0d1a-eabc-4d1d-9db4-dfad2dd49d44', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 10 [renderer: GlyphRenderer(id='f072a16f-c4bd-483f-b32c-13a099914d7e', ...)]

# %%
x1 = normalize(select_plot_migration_movements(df_migration, 'Zimbabwe', 2004, 2018), 'Value')['Normalized_data']    
y1 = normalize(select_plot_foodprices_average(df_foodprices, 'Zimbabwe', 'Cowpeas', 2004, 2018), 'average_price')['Normalized_data']  

output_file("Line.html")

# Create a figure (that's 600x600)
f = figure(plot_width=600, plot_height=600)
f.xaxis.axis_label = "Temperature and precipitation"
f.yaxis.axis_label = "Average foodprices"

# Plot the line
f.circle(x1, y1, color='red')

show(f)
# Out:
# c:\users\boble\appdata\local\programs\python\python36-32\lib\site-packages\bokeh\models\sources.py:110: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 161), ('y', 22)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))

# %%
# checks if a product is in the foodprices dataset, if not, it returns a list of all available products in a given country
def check_product_in_foodprices(set_country, set_product, foodprices):
    
    set_product = '-' + set_product
    product_list = []
    for product in foodprices.loc[foodprices['adm0_name'] == set_country]['cm_name']:
        if '-' + product not in product_list:
            product_list.append('-' + product)

    d = {'Product_List' : product_list}

    df = pd.DataFrame(data=d)    
    
    if not set_product in product_list:
        print('Error, product not recognized. Choose a product from the list below')
        return df
    else:
        return 'Succesfully imported values!'

# %%
import holoviews as hv
from bokeh.io import show, output_file
from bokeh.models import FactorRange
from bokeh.plotting import figure
import bokeh.layouts
from bokeh.layouts import column
hv.extension('bokeh', 'matplotlib')

def normalise(input_data):

    values = []
    
    for value in input_data:
         values.append(value)
            
    Min = min(values)
    Max = max(values)
        
    output_data = []
    
    for value in input_data:
        output_data.append((value - Min)/(Max - Min))
    
    input_data['Normalized_data'] = output_data

    return input_data

def select_plot_temperature_and_precipitation(input_data, country, year1, year2):
    
    x_range = range(year1,year2)
    
    saved_dict = {'mauritania': 'MRT', 'lesotho': 'LSO', 'somalia': 'SOM', 'nigeria': 'NGA', 'tanzania': 'TZA', 'zambia': 'ZMB', 'burundi': 'BDI', 'afghanistan': 'AFG', 'mali': 'MLI', 'niger': 'NER', 'malawi': 'MWI', 'congo': 'ZAR', 'cabo verde': 'CPV', 'Sudan': 'SDN', 'pakistan': 'PAK', 'burkina faso': 'BFA', 'rwanda': 'RWA', 'kenia': 'KEN', 'senegal': 'SEN', 'cameroon': 'CMR', 'sierra leone': 'SLE', 'iraq': 'IRQ', 'uganda': 'UGA', 'mozambique': 'MOZ', 'zimbabwe': 'ZWE', 'central african republic': 'CAF', 'ethiopia': 'ETH', 'guinea': 'GIN', 'liberia': 'LBR', 'djibouti': 'DJI', 'iran': 'IRN', 'madagascar': 'MDG', 'lebanon': 'LBN'}

    if country in saved_dict.keys():
        country = saved_dict[country]
    else:
        print("Please enter correct country name")
    
    input_data = pd.DataFrame(input_data.loc[input_data['country'] == country])
    input_data = input_data.loc[(input_data['year'] > year1 - 1) & (input_data['year'] < year2 + 1)]
    
#   maak van de jaren en maanden kommajaren
    YearMonth = []
    month = []
    for row in input_data['month']:
        month.append(str(row))
        
    count = 0
    
    for year in input_data['year']:
        
        year = int(year) + (int(month[count])  - 1)/ 12
        YearMonth.append(year)
        count += 1
        
    input_data['YearMonth'] = YearMonth
    input_data = input_data[['pr', 'tas', 'country', 'YearMonth']]
    
    
    return input_data


def bar_graph(input_data, country, year1, year2, target_data1, target_data2):
    
    frame = select_plot_temperature_and_precipitation(input_data, country, year1, year2)

    df1 = normalise(frame[target_data1])
    df2 = normalise(frame[target_data2])
    
    #print(df1)
    
    for cell in df1:
        if type(cell) == list:
            
            data_inject1 = cell
            break
            
    for cell in df2:

        if type(cell) == list:
            
            data_inject2 = cell
            break

    % output size = 250
    % opts Curve (color='red')
    
    bars = hv.Bars(data_inject1, "{}".format(country), 'precipitation and temperature', label = 'precipitation')
    line = hv.Curve(data_inject2, "{}".format(country), 'precipitation and temperature',label = 'temperature')
    
    # function to call food data 
    
    plot = bars * line  
    
    return plot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-d7afc21f79ed> in <module>()
# ----> 1 import holoviews as hv
#       2 from bokeh.io import show, output_file
#       3 from bokeh.models import FactorRange
#       4 from bokeh.plotting import figure
#       5 import bokeh.layouts
#
# ModuleNotFoundError: No module named 'holoviews'
