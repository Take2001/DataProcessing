# %%
import pandas as pd
import numpy as np

# %%
raw_data = pd.read_csv('Simpele werking pandas.csv')
df = pd.DataFrame(raw_data)

# print alles:
# print(df)

# print specifieke kolommen:
# print(df[['Origin', 'Year']])

# print specifieke rijen:
# print(df[1:11])

# print specifieke rijen van een kolom:
df.loc[df['Territory_of_asylum'] == 'Belgium']
# Out:
# c:\users\boble\appdata\local\programs\python\python36-32\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        Territory_of_asylum                              Origin  Year  \
# 1364               Belgium                         Afghanistan  1999
# 1365               Belgium                         Afghanistan  1999
# 1366               Belgium                         Afghanistan  1999
# 1367               Belgium                         Afghanistan  1999
# 1368               Belgium                         Afghanistan  1999
# 1369               Belgium                         Afghanistan  1999
# 1370               Belgium                         Afghanistan  1999
# 1371               Belgium                         Afghanistan  1999
# 1372               Belgium                         Afghanistan  1999
# ...
