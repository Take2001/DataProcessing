# %%
import pandas as pd

pr = pd.read_excel('pr_1991_2015_afg.xls', usecols = [0])
tas = pd.read_excel('tas_1991_2015_afg.xls')
dataframe = pd.read_excel('tas_1991_2015_afg.xls')

dataframe['pr'] = pr

#pr.to_excel(dataframe, columns=None, startrow=1)
#pr.to_excel(writer, 'tas_1991_2015_afg.xls')

## DataFrame.insert(loc, column, value, allow_duplicates=False)

print(dataframe)
# Out:
#           tas  \tYear   Month  Country   ISO3   ISO2         pr
# 0     0.18512    1991       1      AFG    NaN    NaN   71.06060
# 1     1.59968    1991       2      AFG    NaN    NaN   56.52350
# 2     6.95549    1991       3      AFG    NaN    NaN  128.24400
# 3    13.24830    1991       4      AFG    NaN    NaN   42.55550
# 4    17.41990    1991       5      AFG    NaN    NaN   62.58580
# 5    23.20400    1991       6      AFG    NaN    NaN    5.95879
# 6    25.61840    1991       7      AFG    NaN    NaN    3.55534
# 7    24.21170    1991       8      AFG    NaN    NaN    2.75255
# 8    19.74910    1991       9      AFG    NaN    NaN   16.36680
# 9    13.10750    1991      10      AFG    NaN    NaN    3.00116
# 10    7.53112    1991      11      AFG    NaN    NaN   13.50850
# 11    4.58609    1991      12      AFG    NaN    NaN   37.06490
# 12    1.06128    1992       1      AFG    NaN    NaN   63.38110
# 13    2.87123    1992       2      AFG    NaN    NaN   48.96740
# ...
