# %%
import pandas as pd
# import raw data
fIn=pd.read_csv("wipdata.csv", encoding= "latin1")
# remove useless columns
keep_col = ["adm0_name", "adm1_name", "mkt_name", "cm_name", "cur_name", "pt_name", "um_id", "um_name", "mp_month", "mp_year", "mp_price"]
# select countries
keep_row = ["Burkina faso", "Cabo Verde", "Central African Republic","Burundi", "Democratic Republic of the Congo", "Djibouti", "Ehtiopia", "Gambia", "Guinea", "Kenya", "Lesotho", "Liberia", "Madagascar", "Malawi","Mali", "Mauritania", "Mozambique", "Niger", "Nigeria" , "Rwanda", "Senegal", "Somalia", "South Sudan", "Sudan", "Uganda", "Tanzania", "Zambia", "Zimbabwe"]
afrika = fIn[keep_col]

# %%
af1 = afrika.loc[afrika['adm0_name'] == 'Burkina Faso']
af2 = afrika.loc[afrika['adm0_name'] == 'Cabo Verde']
af3 = afrika.loc[afrika['adm0_name'] == 'Central African Republic']
af4 = afrika.loc[afrika['adm0_name'] == "Burundi"]
af5 = afrika.loc[afrika['adm0_name'] == "Democratic Republic of the Congo"]
af6 = afrika.loc[afrika['adm0_name'] == "Djibouti"]
af7 = afrika.loc[afrika['adm0_name'] == "Ehtiopia"]
af8 = afrika.loc[afrika['adm0_name'] == "Gambia"]
af9 = afrika.loc[afrika['adm0_name'] == "Guinea"]
af10 = afrika.loc[afrika['adm0_name'] == "Kenya"]
af11 = afrika.loc[afrika['adm0_name'] == "Lesotho"]
af12 = afrika.loc[afrika['adm0_name'] == "Liberia"]
af13 = afrika.loc[afrika['adm0_name'] == "Madagascar"]
af14 = afrika.loc[afrika['adm0_name'] == "Malawi"]
af15 = afrika.loc[afrika['adm0_name'] == "Mali"]
af16 = afrika.loc[afrika['adm0_name'] == "Mauritania"]
af17 = afrika.loc[afrika['adm0_name'] == "Mozambique"]
af18 = afrika.loc[afrika['adm0_name'] == "Niger"]
af19 = afrika.loc[afrika['adm0_name'] == "Nigeria"]
af20 = afrika.loc[afrika['adm0_name'] == "Rwanda"]
af21 = afrika.loc[afrika['adm0_name'] == "Senegal"]
af22 = afrika.loc[afrika['adm0_name'] == "Rwanda"]
af23 = afrika.loc[afrika['adm0_name'] == "Rwanda"]
af24 = afrika.loc[afrika['adm0_name'] == "Rwanda"]
af25 = afrika.loc[afrika['adm0_name'] == "Rwanda"]
# Out:
#           adm0_name adm1_name    mkt_name        cm_name cur_name pt_name  \
# 24213  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24214  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24215  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24216  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24217  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24218  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24219  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24220  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24221  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24222  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24223  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24224  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24225  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24226  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24227  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24228  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24229  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24230  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24231  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24232  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24233  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24234  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24235  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24236  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24237  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24238  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24239  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24240  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24241  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# 24242  Burkina Faso  Cascades     Banfora          Maize      XOF  Retail
# ...             ...       ...         ...            ...      ...     ...
# 33351  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33352  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33353  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33354  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33355  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33356  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33357  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33358  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33359  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33360  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33361  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33362  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33363  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33364  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33365  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33366  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33367  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33368  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33369  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33370  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33371  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33372  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33373  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33374  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33375  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33376  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33377  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33378  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33379  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
# 33380  Burkina Faso      Nord  Ouahigouya  Beans (niebe)      XOF  Retail
#
#        um_id um_name  mp_month  mp_year  mp_price
# 24213      5      KG         1     2003  105.6558
# 24214      5      KG         2     2003  103.3953
# 24215      5      KG         3     2003  101.8303
# 24216      5      KG         4     2003  103.3039
# 24217      5      KG         5     2003  103.7575
# 24218      5      KG         6     2003  102.4965
# 24219      5      KG         7     2003   82.3070
# 24220      5      KG         8     2003   76.6009
# 24221      5      KG         9     2003   71.1824
# 24222      5      KG        10     2003   53.1701
# 24223      5      KG        11     2003   52.2340
# 24224      5      KG        12     2003   50.2570
# 24225      5      KG         1     2004   50.3069
# 24226      5      KG         2     2004   48.0672
# 24227      5      KG         3     2004   51.7204
# 24228      5      KG         4     2004   59.2121
# 24229      5      KG         5     2004   62.8178
# 24230      5      KG         6     2004   62.4239
# 24231      5      KG         7     2004   73.8951
# 24232      5      KG         8     2004   75.1852
# 24233      5      KG         9     2004   87.9618
# 24234      5      KG        10     2004   92.6165
# 24235      5      KG        11     2004   88.9691
# 24236      5      KG        12     2004   86.4592
# 24237      5      KG         1     2005   86.6973
# 24238      5      KG         2     2005  114.4360
# 24239      5      KG         3     2005  141.3891
# 24240      5      KG         4     2005  149.0165
# 24241      5      KG         5     2005  158.8906
# 24242      5      KG         6     2005  200.3926
# ...      ...     ...       ...      ...       ...
# 33351      5      KG         4     2015  245.3593
# 33352      5      KG         5     2015  250.9066
# 33353      5      KG         6     2015  260.8685
# 33354      5      KG         7     2015  261.0000
# 33355      5      KG         8     2015  259.0000
# 33356      5      KG         9     2015  266.0000
# 33357      5      KG        10     2015  232.0000
# 33358      5      KG        11     2015  249.0000
# 33359      5      KG        12     2015  250.0000
# 33360      5      KG         1     2016  256.0000
# 33361      5      KG         2     2016  272.0000
# 33362      5      KG         3     2016  253.0000
# 33363      5      KG         4     2016  299.0000
# 33364      5      KG         5     2016  313.0000
# 33365      5      KG         6     2016  328.0000
# 33366      5      KG         8     2016  327.0000
# 33367      5      KG         9     2016  325.0000
# 33368      5      KG        10     2016  248.0000
# 33369      5      KG        11     2016  255.0000
# 33370      5      KG        12     2016  295.0000
# 33371      5      KG         1     2017  326.0000
# 33372      5      KG         2     2017  324.0000
# 33373      5      KG         3     2017  322.0000
# 33374      5      KG         4     2017  327.0000
# 33375      5      KG         5     2017  324.0000
# 33376      5      KG         6     2017  315.0000
# 33377      5      KG         7     2017  324.0000
# 33378      5      KG         8     2017  326.0000
# 33379      5      KG         9     2017  326.0000
# 33380      5      KG        10     2017  287.0000
#
# [9168 rows x 11 columns]
