# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

raw_data = pd.read_csv('data_africa.csv')
df = pd.DataFrame(raw_data)

sorted_by_year = df.sort_values(by=['Year'])

sorted_by_year.plot(x='Year', y='Values')

# %%
sorted_by_year
# Out:
#       Country of residence        Origin  Year      Month  Values
# 0                  Belgium    Cabo Verde  1999   November       1
# 24769              Belgium  Sierra Leone  1999     August      17
# 24768              Belgium  Sierra Leone  1999       July      37
# 24767              Belgium  Sierra Leone  1999       June      24
# 24766              Belgium  Sierra Leone  1999        May      35
# 24765              Belgium  Sierra Leone  1999      April      52
# 24764              Belgium  Sierra Leone  1999      March      65
# 24770              Belgium  Sierra Leone  1999  September      34
# 24763              Belgium  Sierra Leone  1999   February      39
# 24761              Austria  Sierra Leone  1999   December      31
# 24760              Austria  Sierra Leone  1999   November      25
# 24759              Austria  Sierra Leone  1999    October      31
# 24758              Austria  Sierra Leone  1999  September      23
# ...
