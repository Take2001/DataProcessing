# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

raw_data = pd.read_csv('data_africa.csv')
df = pd.DataFrame(raw_data)

sorted_by_date = df.sort_values(by=['YearMonth'])

#sorted_by_date.plot(x='YearMonth', y='Values')

af1 = sorted_by_date.loc[df['Origin'] == 'Burkina faso']
af2 = sorted_by_date.loc[df['Origin'] == 'Cabo Verde']
af3 = sorted_by_date.loc[df['Origin'] == 'Centrale Afrikaanse Republiek']
af4 = sorted_by_date.loc[df['Origin'] == 'Burundi']
af5 = sorted_by_date.loc[df['Origin'] == 'Democratic Republic of the Congo']
af6 = sorted_by_date.loc[df['Origin'] == 'Djibouti']
af7 = sorted_by_date.loc[df['Origin'] == 'Ehtiopië']
af8 = sorted_by_date.loc[df['Origin'] == 'Gambië']
af9 = sorted_by_date.loc[df['Origin'] == 'Guinea']
af10 = sorted_by_date.loc[df['Origin'] == 'Kenia']
af11 = sorted_by_date.loc[df['Origin'] == 'Lesotho']
af12 = sorted_by_date.loc[df['Origin'] == 'Liberië']
af13 = sorted_by_date.loc[df['Origin'] == 'Madagascar']
af14 = sorted_by_date.loc[df['Origin'] == 'Malawi']
af15 = sorted_by_date.loc[df['Origin'] == 'Mali']
af16 = sorted_by_date.loc[df['Origin'] == 'Mauritanië']
af17 = sorted_by_date.loc[df['Origin'] == 'Mozambique']
af18 = sorted_by_date.loc[df['Origin'] == 'Niger']
af19 = sorted_by_date.loc[df['Origin'] == 'Nigeria']
af20 = sorted_by_date.loc[df['Origin'] == 'Rwanda']
af21 = sorted_by_date.loc[df['Origin'] == 'Senegal']
af22 = sorted_by_date.loc[df['Origin'] == 'Sierra Leone']
af23 = sorted_by_date.loc[df['Origin'] == 'Somalië']
af24 = sorted_by_date.loc[df['Origin'] == 'Zuid-Sudan']
af25 = sorted_by_date.loc[df['Origin'] == 'Sudan']
af26 = sorted_by_date.loc[df['Origin'] == 'Uganda']
af27 = sorted_by_date.loc[df['Origin'] == 'Tanzania']
af28 = sorted_by_date.loc[df['Origin'] == 'Zambia']
af29 = sorted_by_date.loc[df['Origin'] == 'Zimbabwe']

#af2['Values']
#sorted_by_date
plt.hold(True)
x_values = sorted_by_date['YearMonth']

for 
y_values = af2['Values']
#y_values2 = af4['Values']
plt.plot(x_values,y_values)
#plt.plot(x_values,y_values2,c='blue')
# Out:
# c:\users\midas\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:44: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
# c:\users\midas\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\__init__.py:805: MatplotlibDeprecationWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   mplDeprecation)
# c:\users\midas\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\rcsetup.py:155: MatplotlibDeprecationWarning: axes.hold is deprecated, will be removed in 3.0
#   mplDeprecation)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-763041bd4ede> in <module>()
#      46 y_values = af2['Values']
# ...

# %%
sorted_by_date
# Out:
#                                     Country of residence    Origin  \
# 3539                                              France    Guinea
# 2599                                             Belgium  Djibouti
# 19180                                             Greece    Rwanda
# 3608                                          USA (EOIR)    Guinea
# 13315                                         Czech Rep.   Nigeria
# 19186                                            Ireland    Rwanda
# 19196                                        Netherlands    Rwanda
# 13303                                             Canada   Nigeria
# 19208                                             Norway    Rwanda
# 36629                                             Canada  Zimbabwe
# 36628                                            Austria  Zimbabwe
# 19216                                              Spain    Rwanda
# 19222                                             Sweden    Rwanda
# ...
