# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.savefig("brood.png")
fIn=pd.read_csv("Food_prizes_MiddleEast_processed.csv", encoding= "latin1")
keep_col = ["adm0_name", "adm1_name", "mkt_name", "cm_name", "cur_name", "pt_name", "um_id", "um_name", "mp_month", "mp_year", "mp_price"]
me1 = fIn.loc[fIn['adm0_name'] == 'Afghanistan']
me1_market = me1.loc[me1['mkt_name'] == 'Fayzabad']
me1_product = me1_market.loc[me1_market['cm_name'] == 'Bread']
x_values = me1_product['mp_year']
y_values = me1_product['mp_price']

plt.plot(x_values, y_values)

# %%
me1
# Out:
#        Unnamed: 0    adm0_name   adm1_name  mkt_name             cm_name  \
# 24072           0  Afghanistan  Badakhshan  Fayzabad               Bread
# 24073           1  Afghanistan  Badakhshan  Fayzabad               Bread
# 24074           2  Afghanistan  Badakhshan  Fayzabad               Bread
# 24075           3  Afghanistan  Badakhshan  Fayzabad               Bread
# 24076           4  Afghanistan  Badakhshan  Fayzabad               Bread
# 24077           5  Afghanistan  Badakhshan  Fayzabad               Bread
# 24078           6  Afghanistan  Badakhshan  Fayzabad               Bread
# 24079           7  Afghanistan  Badakhshan  Fayzabad               Bread
# 24080           8  Afghanistan  Badakhshan  Fayzabad               Bread
# 24081           9  Afghanistan  Badakhshan  Fayzabad               Bread
# 24082          10  Afghanistan  Badakhshan  Fayzabad               Bread
# 24083          11  Afghanistan  Badakhshan  Fayzabad               Bread
# ...
