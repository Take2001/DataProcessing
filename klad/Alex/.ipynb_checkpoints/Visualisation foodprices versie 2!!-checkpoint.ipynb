# %%
import pandas as pd
import matplotlib.pyplot as plt
from bokeh.plotting import figure
from bokeh.io import output_file, show, save
foodprices = pd.read_csv("Food_prizes_MiddleEast_and_Africa_processed.csv", encoding= "latin1")

# %% [markdown]
# # Producten per land

# %% [markdown]
# # Midden Oosten

# %%
# Laat zien wat de gemiddelde prijs van een product in een land in het Midden Oosten is
middle_east=pd.read_csv("Food_prizes_MiddleEast_processed.csv", encoding= "latin1")

def plotprice(country, product):
    # kies land 
    me_country = middle_east.loc[middle_east['adm0_name'] == country]
    
    #maak een lijst van de markten in dat land
    markets = me_country.groupby('mkt_name')['adm0_name']
    market_list = markets.count()
    markets_in_country = market_list.index.tolist()
    
    # itereer over markten
    for market in markets_in_country:
        markt = me_country.loc[middle_east['mkt_name'] == market]
        eten = markt.loc[markt['cm_name'] == product]
        prijs = eten['mp_price']
        
        # plot de grafiek
        x_values = eten['Year']
        y_values = prijs
        f = figure(plot_width=600, plot_height=600)
        f.line(x_values, y_values)
        output_file("prijzen_me.html")
        save(f)

# %%
plotprice('State of Palestine', 'Potatoes (medium size)')

# %%
# laat zien welke producten er in een bepaald land te koop zijn

# laat zien welke producten er in een bepaald land te koop zijn voor een bepaalde input_data
def products_country(input_data, country):
    products = []
    fp_country = foodprices.loc[input_data['adm0_name'] == country]
    products_total = fp_country['cm_name']
    product_list = products_total.tolist()
    for item in product_list:
        if item not in products:
            products.append(item)
    return(sorted(products))
products_country(foodprices, 'Rwanda')
# Out:
# ['Apples (red)',
#  'Avocados',
#  'Bananas',
#  'Beans (dry)',
#  'Beans (green, fresh)',
#  'Cabbage',
#  'Carrots',
#  'Cassava',
#  'Cassava flour',
#  'Cassava leaves',
#  'Cauliflower',
#  'Charcoal',
#  'Chili (red)',
#  'Cucumbers (greenhouse)',
#  'Eggplants',
#  'Eggs',
#  'Garlic',
#  'Groundnuts (shelled)',
#  'Guava',
#  'Livestock (Goat)',
#  'Livestock (Sheep)',
#  'Livestock (cattle)',
#  'Livestock (hen)',
#  'Livestock (pig)',
#  'Maize',
#  'Maize flour',
#  'Maize flour (imported)',
#  'Mangoes',
#  'Meat (beef)',
#  'Meat (goat)',
#  'Meat (mutton)',
#  'Meat (pork)',
#  'Milk',
#  'Onions (red)',
#  'Onions (white)',
#  'Oranges (big size)',
#  'Papaya',
#  'Passion fruit',
#  'Peas (dry)',
#  'Peas (fresh)',
#  'Peppers (green)',
#  'Potatoes (Irish)',
#  'Rice',
#  'Rice (imported, Indian)',
#  'Rice (imported, Tanzanian)',
#  'Rice (local)',
#  'Sorghum',
#  'Sorghum flour',
#  'Soybeans',
#  'Spinach',
#  'Sweet potatoes',
#  'Tomatoes',
#  'Wheat',
#  'Wheat flour',
#  'Zucchini']

# %%
country = foodprices.loc[foodprices['adm0_name'] == 'Gambia']
product = country.loc[country['cm_name'] == 'Rice (medium grain, imported)']
product.to_csv("gambiarijst.csv", encoding="utf-8", index=True)
# Out:
#        Unnamed: 0  Unnamed: 0.1 adm0_name                    adm1_name  \
# 49705       49705        118666    Gambia  $Kanifing Municipal Council
# 49706       49706        118667    Gambia  $Kanifing Municipal Council
# 49707       49707        118668    Gambia  $Kanifing Municipal Council
# 49708       49708        118669    Gambia  $Kanifing Municipal Council
# 49709       49709        118670    Gambia  $Kanifing Municipal Council
# 49710       49710        118671    Gambia  $Kanifing Municipal Council
# 49711       49711        118672    Gambia  $Kanifing Municipal Council
# 49712       49712        118673    Gambia  $Kanifing Municipal Council
# 49713       49713        118674    Gambia  $Kanifing Municipal Council
# 49714       49714        118675    Gambia  $Kanifing Municipal Council
# 49715       49715        118676    Gambia  $Kanifing Municipal Council
# 49716       49716        118677    Gambia  $Kanifing Municipal Council
# 49717       49717        118678    Gambia  $Kanifing Municipal Council
# 49718       49718        118679    Gambia  $Kanifing Municipal Council
# 49719       49719        118680    Gambia  $Kanifing Municipal Council
# 49720       49720        118681    Gambia  $Kanifing Municipal Council
# 49721       49721        118682    Gambia  $Kanifing Municipal Council
# 49722       49722        118683    Gambia  $Kanifing Municipal Council
# 49723       49723        118684    Gambia  $Kanifing Municipal Council
# 49724       49724        118685    Gambia  $Kanifing Municipal Council
# 49725       49725        118686    Gambia  $Kanifing Municipal Council
# 49726       49726        118687    Gambia  $Kanifing Municipal Council
# 49727       49727        118688    Gambia  $Kanifing Municipal Council
# 49728       49728        118689    Gambia  $Kanifing Municipal Council
# 49729       49729        118690    Gambia  $Kanifing Municipal Council
# 49730       49730        118691    Gambia  $Kanifing Municipal Council
# 49731       49731        118692    Gambia  $Kanifing Municipal Council
# 49732       49732        118693    Gambia  $Kanifing Municipal Council
# 49733       49733        118694    Gambia  $Kanifing Municipal Council
# 49734       49734        118695    Gambia  $Kanifing Municipal Council
# ...           ...           ...       ...                          ...
# 71937       71937        140898    Gambia                Central River
# 71938       71938        140899    Gambia                Central River
# 71939       71939        140900    Gambia                Central River
# 71940       71940        140901    Gambia                Central River
# 71941       71941        140902    Gambia                Central River
# 71942       71942        140903    Gambia                Central River
# 71943       71943        140904    Gambia                Central River
# 71944       71944        140905    Gambia                Central River
# 71945       71945        140906    Gambia                Central River
# 71946       71946        140907    Gambia                Central River
# 71947       71947        140908    Gambia                Central River
# 71948       71948        140909    Gambia                Central River
# 71949       71949        140910    Gambia                Central River
# 71950       71950        140911    Gambia                Central River
# 71951       71951        140912    Gambia                Central River
# 71952       71952        140913    Gambia                Central River
# 71953       71953        140914    Gambia                Central River
# 71954       71954        140915    Gambia                Central River
# 71955       71955        140916    Gambia                Central River
# 71956       71956        140917    Gambia                Central River
# 71957       71957        140918    Gambia                Central River
# 71958       71958        140919    Gambia                Central River
# 71959       71959        140920    Gambia                Central River
# 71960       71960        140921    Gambia                Central River
# 71961       71961        140922    Gambia                Central River
# 71962       71962        140923    Gambia                Central River
# 71963       71963        140924    Gambia                Central River
# 71964       71964        140925    Gambia                Central River
# 71965       71965        140926    Gambia                Central River
# 71966       71966        140927    Gambia                Central River
#
#       mkt_name                        cm_name cur_name pt_name  um_id um_name  \
# 49705    Bakau  Rice (medium grain, imported)      GMD  Retail     28   500 G
# 49706    Bakau  Rice (medium grain, imported)      GMD  Retail     28   500 G
# 49707    Bakau  Rice (medium grain, imported)      GMD  Retail     28   500 G
# 49708    Bakau  Rice (medium grain, imported)      GMD  Retail     28   500 G
# 49709    Bakau  Rice (medium grain, imported)      GMD  Retail     28   500 G
# 49710    Bakau  Rice (medium grain, imported)      GMD  Retail     28   500 G
# 49711    Bakau  Rice (medium grain, imported)      GMD  Retail     28   500 G
# 49712    Bakau  Rice (medium grain, imported)      GMD  Retail     28   500 G
# 49713    Bakau  Rice (medium grain, imported)      GMD  Retail     28   500 G
# 49714    Bakau  Rice (medium grain, imported)      GMD  Retail     28   500 G
# 49715    Bakau  Rice (medium grain, imported)      GMD  Retail     28   500 G
# 49716    Bakau  Rice (medium grain, imported)      GMD  Retail     28   500 G
# 49717    Bakau  Rice (medium grain, imported)      GMD  Retail     28   500 G
# 49718    Bakau  Rice (medium grain, imported)      GMD  Retail     28   500 G
# 49719    Bakau  Rice (medium grain, imported)      GMD  Retail     28   500 G
# 49720    Bakau  Rice (medium grain, imported)      GMD  Retail     28   500 G
# 49721    Bakau  Rice (medium grain, imported)      GMD  Retail     28   500 G
# 49722    Bakau  Rice (medium grain, imported)      GMD  Retail     28   500 G
# 49723    Bakau  Rice (medium grain, imported)      GMD  Retail     28   500 G
# 49724    Bakau  Rice (medium grain, imported)      GMD  Retail     28   500 G
# 49725    Bakau  Rice (medium grain, imported)      GMD  Retail     28   500 G
# 49726    Bakau  Rice (medium grain, imported)      GMD  Retail     28   500 G
# 49727    Bakau  Rice (medium grain, imported)      GMD  Retail     28   500 G
# 